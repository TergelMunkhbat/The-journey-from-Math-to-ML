# %% [markdown]
# # The Journey from Mathematics to Machine Learning

# %% [markdown]
# ## Series 1: Linear algebra

# %% [markdown]
# ### Episode 8: Word Embedding - Word2Vec - continuous bag-of-words (CBOW)

# %% [markdown]
# - NLP (Jupyter Notebook)
#     1. [Learning richer meanings from IMDB movie reviews](#1.-Learning-richer-meanings-from-IMDB-movie-reviews)
#     2. [Word analogies (Dad - Men + Women ~= Mom)](#2.-Word-analogies-(Dad---Men-+-Women-~=-Mom))

# %% [raw]
# # Fill-in-the blank task
# Infinite training data
# Need to understand the context

# %% [markdown]
# ## 1. Learning richer meanings from IMDB movie reviews

# %%
import numpy as np

# %% [markdown]
# ### Data

# %%
with open('dataset/reviews.txt') as f:
    raw_reviews = f.readlines()

# %% [markdown]
# #### Preparing the input dataset

# %%
tokens = []
for review in raw_reviews:
    review = list(review.split(' '))
    review = list(filter(('').__ne__, review))
    review = list(filter(('.').__ne__, review))
    review = list(filter(('\n').__ne__, review))
    tokens.append(list(review))

# %%
words = set()
for review in tokens:
    for word in review:
        words.add(word)
words = list(words)

# %%
len(words)
# Out:
# 74072

# %%
word_to_index = {}
for i, word in enumerate(words):
    word_to_index[word] = i

# %% [markdown]
# ### Network

# %% [markdown]
# #### Linear Layer

# %%
class Layer_Linear:
    """Representing a neural network layer"""
    
    def __init__(self, n_inputs, n_outputs, use_bias=True):
        """Initlize weights and bias"""
        self.weights = 0.01 * np.random.randn(n_inputs, n_outputs)
        self.use_bias = use_bias
        if self.use_bias:
            self.biases = np.zeros((1, n_outputs))
    
    def forward(self, inputs):
        """
        It multiplies the inputs by the weights 
        and then sums them, and then sums bias.
        """
        #To calculate gradient, remembering input values
        self.inputs = inputs
        #Calculate outputs' values
        if self.use_bias:
            self.output = np.dot(inputs, self.weights) + self.biases
        else:
            self.output = np.dot(inputs, self.weights)
    
    def backward(self, dvalues):
        """Gradient with respect to parameters and input"""
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dresults = np.dot(dvalues, self.weights.T)
        if self.use_bias:
            self.dbiases = np.sum(dvalues, axis=0, keepdims=True)

# %% [markdown]
# #### Activation functions

# %%
class Activation_ReLU:
    """ReLU activation"""
    
    def forward(self, inputs):
        """Forward pass"""
        
        #To calculate gradient, remembering input values
        self.inputs = inputs
        
        #Calculate outputs' values
        self.output = np.maximum(0, inputs)
        
    def backward(self, dvalues):
        """Backward pass"""
        
        self.dresults = self.inputs > 0
        self.dresults = self.dresults * dvalues

# %%
class Activation_Softmax:
    """Softmax activation"""
    
    def forward(self, inputs):
        """Forward pass"""
        
        #Compute e^x for each element of inputs
        #Due to the overflow error, 
        #Maximum value of per sample subtract from each row
        exp_values = np.exp(inputs - np.max(inputs, axis=1,
                                           keepdims=True))
        
        #Normalize them for each batch
        self.output = exp_values / np.sum(exp_values, 
                                          axis=1, keepdims=True)
    
    def backward(self, dvalues):
        """Gradient softmax"""
        
        #Initialize an array
        self.dresults = np.zeros(dvalues.shape)
        
        for i in range(len(dvalues)):
            #Reshape the single output
            single_output = self.output[i].reshape(-1, 1)
            
            #Calculate Jacobian matrix of the single output
            jacobian_matrix = np.diagflat(single_output) - \
                                np.dot(single_output, single_output.T)
            
            #Multiply the Jacobian matrix by the loss function derivative
            self.dresults[i] = np.dot(jacobian_matrix, dvalues[i])

# %% [markdown]
# #### Loss function

# %%
class Loss_CategoricalCrossEntropy():
    """Cross entropy Loss function"""
    
    def forward(self, y_pred, y_true):
        """Forward pass"""
        y_pred += 1e-10
        y_pred = np.clip(y_pred, None, 1)
        true_prediction = np.sum(y_pred * y_true, axis=1)
        error = np.mean(-np.log(true_prediction)) 
        return error
    
    def backward(self, y_pred, y_true):
        """Derivative of CCE with respect to preds"""
        
        #Number of samples
        samples = len(y_pred)
        
        self.dresults = -y_true / (y_pred * samples)

# %% [markdown]
# #### Categorical Cross-entropy + Softmax

# %%
class Loss_CategoricalCrossEntropy_Activation_SoftMax:
    """Cateogircal cross entropy loss and SoftMax function"""
    
    def __init__(self):
        """Initialize Softmax and CCE loss"""
        self.activation = Activation_Softmax()
        self.loss = Loss_CategoricalCrossEntropy()
        
    def forward(self, inputs, y_true):
        """Forward pass"""
        self.activation.forward(inputs)
        return self.loss.forward(self.activation.output, y_true)
    
    def backward(self, y_pred, y_true):
        """Gradient of Categorical cross entropy + Softmax activation"""
        samples = len(y_pred)
        
        self.dresults = (y_pred - y_true) / samples

# %% [markdown]
# #### Optimizer

# %%
class Optimizer_GD:
    """Gradient descent optimizer"""
    
    def __init__(self, alpha=1.):
        """Initialize hyperparameters"""
        self.alpha = alpha

    def update_parameters(self, layer):
        """Update parameters"""
        
        weights_delta = layer.dweights * self.alpha
        layer.weights -= weights_delta
        
        if layer.use_bias:
            biases_delta = layer.dbiases * self.alpha
            layer.biases -= biases_delta

# %% [markdown]
# ### Hyperparameter

# %%
max_epoch = 1
alpha = 0.1
window = 2
negative = 5

# %% [markdown]
# ### Initialize the model

# %%
layer1 = Layer_Linear(len(words), 60, use_bias=False)
activation1 = Activation_ReLU()

layer2 = Layer_Linear(60, len(words), use_bias=False)

# %% [markdown]
# #### Initlize optimizer and loss function

# %%
loss = Loss_CategoricalCrossEntropy_Activation_SoftMax()
optimizer = Optimizer_GD(alpha)

# %% [markdown]
# ### Training the model

# %%
train_error = 0
for rev_i, review in enumerate(tokens * max_epoch):
    
    for j in range(len(review)):
        
        # Prepare the true value
        true_i = [word_to_index[review[j]]] + (np.random.rand(negative) * len(words)).astype('int').tolist()
        true = np.zeros((1, negative + 1))
        true[0, 0] = 1
        
        # Prepare the context
        left_context = review[max(0, j-window):j]
        right_context = review[j+1:min(len(review), j+window+1)]
        context = left_context + right_context
        context_i = list(map(lambda x: word_to_index[x], context))
        # Prepare the input
        inputs = np.zeros((1, len(words)))
        inputs[0, context_i] = 1
        
        # Forward pass
        layer1.inputs = inputs
        layer1.output = np.sum(layer1.weights[context_i], axis=0, keepdims=True)
        activation1.forward(layer1.output)
    
        layer2.inputs = activation1.output
        layer2.output = np.dot(layer2.inputs, layer2.weights[:, true_i])
        train_error += loss.forward(layer2.output, true) / len(review)
        
        #Backward pass
        loss.backward(loss.activation.output, true)
        
        layer2.dweights = np.dot(layer2.inputs.T, loss.dresults)
        layer2.dresults = np.dot(loss.dresults, layer2.weights.T[true_i])
        
        activation1.backward(layer2.dresults)
        layer1.backward(activation1.dresults)
        
        #Update parameters
        weights_delta = layer2.dweights * optimizer.alpha
        layer2.weights[:, true_i] -= weights_delta
        optimizer.update_parameters(layer1)

    print(f'rev_i: {rev_i},',
          f'Train error: {train_error/(rev_i+1):.3f},')
# Out:
# rev_i: 0, Train error: 1.791,
# rev_i: 1, Train error: 1.791,
# rev_i: 2, Train error: 1.791,
# rev_i: 3, Train error: 1.781,
# rev_i: 4, Train error: 1.755,
# rev_i: 5, Train error: 1.722,
# rev_i: 6, Train error: 1.687,
# rev_i: 7, Train error: 1.656,
# rev_i: 8, Train error: 1.606,
# rev_i: 9, Train error: 1.567,
# rev_i: 10, Train error: 1.518,
# rev_i: 11, Train error: 1.477,
# rev_i: 12, Train error: 1.442,
# rev_i: 13, Train error: 1.414,
# rev_i: 14, Train error: 1.394,
# rev_i: 15, Train error: 1.359,
# rev_i: 16, Train error: 1.332,
# rev_i: 17, Train error: 1.307,
# rev_i: 18, Train error: 1.278,
# rev_i: 19, Train error: 1.242,
# rev_i: 20, Train error: 1.214,
# rev_i: 21, Train error: 1.186,
# rev_i: 22, Train error: 1.163,
# rev_i: 23, Train error: 1.138,
# rev_i: 24, Train error: 1.124,
# rev_i: 25, Train error: 1.110,
# rev_i: 26, Train error: 1.085,
# rev_i: 27, Train error: 1.065,
# rev_i: 28, Train error: 1.040,
# rev_i: 29, Train error: 1.017,
# rev_i: 30, Train error: 0.999,
# rev_i: 31, Train error: 0.986,
# rev_i: 32, Train error: 0.973,
# rev_i: 33, Train error: 0.958,
# rev_i: 34, Train error: 0.947,
# rev_i: 35, Train error: 0.941,
# rev_i: 36, Train error: 0.925,
# rev_i: 37, Train error: 0.915,
# rev_i: 38, Train error: 0.904,
# rev_i: 39, Train error: 0.904,
# rev_i: 40, Train error: 0.893,
# rev_i: 41, Train error: 0.882,
# rev_i: 42, Train error: 0.871,
# rev_i: 43, Train error: 0.861,
# rev_i: 44, Train error: 0.858,
# rev_i: 45, Train error: 0.846,
# rev_i: 46, Train error: 0.855,
# rev_i: 47, Train error: 0.850,
# rev_i: 48, Train error: 0.843,
# rev_i: 49, Train error: 0.835,
# rev_i: 50, Train error: 0.831,
# rev_i: 51, Train error: 0.827,
# rev_i: 52, Train error: 0.819,
# rev_i: 53, Train error: 0.815,
# rev_i: 54, Train error: 0.808,
# rev_i: 55, Train error: 0.801,
# rev_i: 56, Train error: 0.793,
# rev_i: 57, Train error: 0.788,
# rev_i: 58, Train error: 0.784,
# rev_i: 59, Train error: 0.775,
# rev_i: 60, Train error: 0.768,
# rev_i: 61, Train error: 0.763,
# rev_i: 62, Train error: 0.754,
# rev_i: 63, Train error: 0.747,
# rev_i: 64, Train error: 0.742,
# rev_i: 65, Train error: 0.736,
# rev_i: 66, Train error: 0.734,
# rev_i: 67, Train error: 0.728,
# rev_i: 68, Train error: 0.724,
# rev_i: 69, Train error: 0.719,
# rev_i: 70, Train error: 0.715,
# rev_i: 71, Train error: 0.710,
# rev_i: 72, Train error: 0.707,
# rev_i: 73, Train error: 0.701,
# rev_i: 74, Train error: 0.695,
# rev_i: 75, Train error: 0.691,
# rev_i: 76, Train error: 0.688,
# rev_i: 77, Train error: 0.683,
# rev_i: 78, Train error: 0.681,
# rev_i: 79, Train error: 0.679,
# rev_i: 80, Train error: 0.675,
# rev_i: 81, Train error: 0.671,
# rev_i: 82, Train error: 0.666,
# rev_i: 83, Train error: 0.662,
# rev_i: 84, Train error: 0.657,
# rev_i: 85, Train error: 0.654,
# rev_i: 86, Train error: 0.651,
# rev_i: 87, Train error: 0.648,
# rev_i: 88, Train error: 0.650,
# rev_i: 89, Train error: 0.647,
# rev_i: 90, Train error: 0.644,
# rev_i: 91, Train error: 0.643,
# rev_i: 92, Train error: 0.640,
# rev_i: 93, Train error: 0.638,
# rev_i: 94, Train error: 0.638,
# rev_i: 95, Train error: 0.635,
# rev_i: 96, Train error: 0.632,
# rev_i: 97, Train error: 0.630,
# rev_i: 98, Train error: 0.628,
# rev_i: 99, Train error: 0.625,
# rev_i: 100, Train error: 0.621,
# rev_i: 101, Train error: 0.617,
# rev_i: 102, Train error: 0.614,
# rev_i: 103, Train error: 0.615,
# rev_i: 104, Train error: 0.612,
# rev_i: 105, Train error: 0.610,
# rev_i: 106, Train error: 0.606,
# rev_i: 107, Train error: 0.605,
# rev_i: 108, Train error: 0.602,
# rev_i: 109, Train error: 0.602,
# rev_i: 110, Train error: 0.602,
# rev_i: 111, Train error: 0.605,
# rev_i: 112, Train error: 0.604,
# rev_i: 113, Train error: 0.603,
# rev_i: 114, Train error: 0.601,
# rev_i: 115, Train error: 0.599,
# rev_i: 116, Train error: 0.597,
# rev_i: 117, Train error: 0.597,
# rev_i: 118, Train error: 0.595,
# rev_i: 119, Train error: 0.594,
# rev_i: 120, Train error: 0.590,
# rev_i: 121, Train error: 0.589,
# rev_i: 122, Train error: 0.588,
# rev_i: 123, Train error: 0.586,
# rev_i: 124, Train error: 0.584,
# rev_i: 125, Train error: 0.584,
# rev_i: 126, Train error: 0.582,
# rev_i: 127, Train error: 0.581,
# rev_i: 128, Train error: 0.581,
# rev_i: 129, Train error: 0.579,
# rev_i: 130, Train error: 0.577,
# rev_i: 131, Train error: 0.577,
# rev_i: 132, Train error: 0.575,
# rev_i: 133, Train error: 0.573,
# rev_i: 134, Train error: 0.571,
# rev_i: 135, Train error: 0.571,
# rev_i: 136, Train error: 0.569,
# rev_i: 137, Train error: 0.569,
# rev_i: 138, Train error: 0.569,
# rev_i: 139, Train error: 0.567,
# rev_i: 140, Train error: 0.568,
# rev_i: 141, Train error: 0.566,
# rev_i: 142, Train error: 0.566,
# rev_i: 143, Train error: 0.564,
# rev_i: 144, Train error: 0.563,
# rev_i: 145, Train error: 0.561,
# rev_i: 146, Train error: 0.559,
# rev_i: 147, Train error: 0.558,
# rev_i: 148, Train error: 0.557,
# rev_i: 149, Train error: 0.556,
# rev_i: 150, Train error: 0.555,
# rev_i: 151, Train error: 0.555,
# rev_i: 152, Train error: 0.554,
# rev_i: 153, Train error: 0.553,
# rev_i: 154, Train error: 0.551,
# rev_i: 155, Train error: 0.550,
# rev_i: 156, Train error: 0.548,
# rev_i: 157, Train error: 0.550,
# rev_i: 158, Train error: 0.550,
# rev_i: 159, Train error: 0.549,
# rev_i: 160, Train error: 0.549,
# rev_i: 161, Train error: 0.547,
# rev_i: 162, Train error: 0.546,
# rev_i: 163, Train error: 0.547,
# rev_i: 164, Train error: 0.547,
# rev_i: 165, Train error: 0.546,
# rev_i: 166, Train error: 0.544,
# rev_i: 167, Train error: 0.544,
# rev_i: 168, Train error: 0.542,
# rev_i: 169, Train error: 0.542,
# rev_i: 170, Train error: 0.539,
# rev_i: 171, Train error: 0.538,
# rev_i: 172, Train error: 0.537,
# rev_i: 173, Train error: 0.536,
# rev_i: 174, Train error: 0.535,
# rev_i: 175, Train error: 0.534,
# rev_i: 176, Train error: 0.534,
# rev_i: 177, Train error: 0.532,
# rev_i: 178, Train error: 0.532,
# rev_i: 179, Train error: 0.531,
# rev_i: 180, Train error: 0.530,
# rev_i: 181, Train error: 0.529,
# rev_i: 182, Train error: 0.527,
# rev_i: 183, Train error: 0.526,
# rev_i: 184, Train error: 0.525,
# rev_i: 185, Train error: 0.524,
# rev_i: 186, Train error: 0.522,
# rev_i: 187, Train error: 0.522,
# rev_i: 188, Train error: 0.520,
# rev_i: 189, Train error: 0.519,
# rev_i: 190, Train error: 0.520,
# rev_i: 191, Train error: 0.518,
# rev_i: 192, Train error: 0.518,
# rev_i: 193, Train error: 0.518,
# rev_i: 194, Train error: 0.519,
# rev_i: 195, Train error: 0.518,
# rev_i: 196, Train error: 0.518,
# rev_i: 197, Train error: 0.518,
# rev_i: 198, Train error: 0.517,
# rev_i: 199, Train error: 0.516,
# rev_i: 200, Train error: 0.516,
# rev_i: 201, Train error: 0.514,
# rev_i: 202, Train error: 0.515,
# rev_i: 203, Train error: 0.514,
# rev_i: 204, Train error: 0.514,
# rev_i: 205, Train error: 0.514,
# rev_i: 206, Train error: 0.515,
# rev_i: 207, Train error: 0.513,
# rev_i: 208, Train error: 0.512,
# rev_i: 209, Train error: 0.511,
# rev_i: 210, Train error: 0.509,
# rev_i: 211, Train error: 0.508,
# rev_i: 212, Train error: 0.508,
# rev_i: 213, Train error: 0.506,
# rev_i: 214, Train error: 0.506,
# rev_i: 215, Train error: 0.505,
# rev_i: 216, Train error: 0.504,
# rev_i: 217, Train error: 0.504,
# rev_i: 218, Train error: 0.503,
# rev_i: 219, Train error: 0.502,
# rev_i: 220, Train error: 0.501,
# rev_i: 221, Train error: 0.501,
# rev_i: 222, Train error: 0.501,
# rev_i: 223, Train error: 0.499,
# rev_i: 224, Train error: 0.499,
# rev_i: 225, Train error: 0.498,
# rev_i: 226, Train error: 0.497,
# rev_i: 227, Train error: 0.496,
# rev_i: 228, Train error: 0.495,
# rev_i: 229, Train error: 0.494,
# rev_i: 230, Train error: 0.494,
# rev_i: 231, Train error: 0.493,
# rev_i: 232, Train error: 0.493,
# rev_i: 233, Train error: 0.492,
# rev_i: 234, Train error: 0.492,
# rev_i: 235, Train error: 0.491,
# rev_i: 236, Train error: 0.491,
# rev_i: 237, Train error: 0.490,
# rev_i: 238, Train error: 0.491,
# rev_i: 239, Train error: 0.489,
# rev_i: 240, Train error: 0.488,
# rev_i: 241, Train error: 0.488,
# rev_i: 242, Train error: 0.487,
# rev_i: 243, Train error: 0.486,
# rev_i: 244, Train error: 0.485,
# rev_i: 245, Train error: 0.484,
# rev_i: 246, Train error: 0.484,
# rev_i: 247, Train error: 0.483,
# rev_i: 248, Train error: 0.483,
# rev_i: 249, Train error: 0.482,
# rev_i: 250, Train error: 0.481,
# rev_i: 251, Train error: 0.480,
# rev_i: 252, Train error: 0.480,
# rev_i: 253, Train error: 0.479,
# rev_i: 254, Train error: 0.478,
# rev_i: 255, Train error: 0.477,
# rev_i: 256, Train error: 0.477,
# rev_i: 257, Train error: 0.476,
# rev_i: 258, Train error: 0.476,
# rev_i: 259, Train error: 0.474,
# rev_i: 260, Train error: 0.474,
# rev_i: 261, Train error: 0.473,
# rev_i: 262, Train error: 0.472,
# rev_i: 263, Train error: 0.473,
# rev_i: 264, Train error: 0.473,
# rev_i: 265, Train error: 0.472,
# rev_i: 266, Train error: 0.471,
# rev_i: 267, Train error: 0.471,
# rev_i: 268, Train error: 0.471,
# rev_i: 269, Train error: 0.470,
# rev_i: 270, Train error: 0.470,
# rev_i: 271, Train error: 0.471,
# rev_i: 272, Train error: 0.470,
# rev_i: 273, Train error: 0.469,
# rev_i: 274, Train error: 0.469,
# rev_i: 275, Train error: 0.469,
# rev_i: 276, Train error: 0.469,
# rev_i: 277, Train error: 0.469,
# rev_i: 278, Train error: 0.468,
# rev_i: 279, Train error: 0.468,
# rev_i: 280, Train error: 0.467,
# rev_i: 281, Train error: 0.468,
# rev_i: 282, Train error: 0.467,
# rev_i: 283, Train error: 0.467,
# rev_i: 284, Train error: 0.467,
# rev_i: 285, Train error: 0.466,
# rev_i: 286, Train error: 0.466,
# rev_i: 287, Train error: 0.465,
# rev_i: 288, Train error: 0.465,
# rev_i: 289, Train error: 0.464,
# rev_i: 290, Train error: 0.464,
# rev_i: 291, Train error: 0.463,
# rev_i: 292, Train error: 0.463,
# rev_i: 293, Train error: 0.462,
# rev_i: 294, Train error: 0.461,
# rev_i: 295, Train error: 0.461,
# rev_i: 296, Train error: 0.461,
# rev_i: 297, Train error: 0.460,
# rev_i: 298, Train error: 0.460,
# rev_i: 299, Train error: 0.459,
# rev_i: 300, Train error: 0.459,
# rev_i: 301, Train error: 0.458,
# rev_i: 302, Train error: 0.458,
# rev_i: 303, Train error: 0.458,
# rev_i: 304, Train error: 0.458,
# rev_i: 305, Train error: 0.458,
# rev_i: 306, Train error: 0.457,
# rev_i: 307, Train error: 0.456,
# rev_i: 308, Train error: 0.456,
# rev_i: 309, Train error: 0.455,
# rev_i: 310, Train error: 0.456,
# rev_i: 311, Train error: 0.456,
# rev_i: 312, Train error: 0.456,
# rev_i: 313, Train error: 0.455,
# rev_i: 314, Train error: 0.454,
# rev_i: 315, Train error: 0.455,
# rev_i: 316, Train error: 0.454,
# rev_i: 317, Train error: 0.454,
# rev_i: 318, Train error: 0.453,
# rev_i: 319, Train error: 0.452,
# rev_i: 320, Train error: 0.452,
# rev_i: 321, Train error: 0.451,
# rev_i: 322, Train error: 0.451,
# rev_i: 323, Train error: 0.451,
# rev_i: 324, Train error: 0.450,
# rev_i: 325, Train error: 0.450,
# rev_i: 326, Train error: 0.449,
# rev_i: 327, Train error: 0.448,
# rev_i: 328, Train error: 0.448,
# rev_i: 329, Train error: 0.448,
# rev_i: 330, Train error: 0.448,
# rev_i: 331, Train error: 0.447,
# rev_i: 332, Train error: 0.447,
# rev_i: 333, Train error: 0.446,
# rev_i: 334, Train error: 0.445,
# rev_i: 335, Train error: 0.446,
# rev_i: 336, Train error: 0.444,
# rev_i: 337, Train error: 0.445,
# rev_i: 338, Train error: 0.444,
# rev_i: 339, Train error: 0.444,
# rev_i: 340, Train error: 0.443,
# rev_i: 341, Train error: 0.443,
# rev_i: 342, Train error: 0.442,
# rev_i: 343, Train error: 0.441,
# rev_i: 344, Train error: 0.441,
# rev_i: 345, Train error: 0.440,
# rev_i: 346, Train error: 0.441,
# rev_i: 347, Train error: 0.440,
# rev_i: 348, Train error: 0.440,
# rev_i: 349, Train error: 0.439,
# rev_i: 350, Train error: 0.439,
# rev_i: 351, Train error: 0.438,
# rev_i: 352, Train error: 0.438,
# rev_i: 353, Train error: 0.438,
# rev_i: 354, Train error: 0.437,
# rev_i: 355, Train error: 0.437,
# rev_i: 356, Train error: 0.436,
# rev_i: 357, Train error: 0.436,
# rev_i: 358, Train error: 0.436,
# rev_i: 359, Train error: 0.436,
# rev_i: 360, Train error: 0.435,
# rev_i: 361, Train error: 0.435,
# rev_i: 362, Train error: 0.434,
# rev_i: 363, Train error: 0.434,
# rev_i: 364, Train error: 0.434,
# rev_i: 365, Train error: 0.433,
# rev_i: 366, Train error: 0.433,
# rev_i: 367, Train error: 0.432,
# rev_i: 368, Train error: 0.432,
# rev_i: 369, Train error: 0.432,
# rev_i: 370, Train error: 0.431,
# rev_i: 371, Train error: 0.431,
# rev_i: 372, Train error: 0.430,
# rev_i: 373, Train error: 0.430,
# rev_i: 374, Train error: 0.429,
# rev_i: 375, Train error: 0.428,
# rev_i: 376, Train error: 0.428,
# rev_i: 377, Train error: 0.427,
# rev_i: 378, Train error: 0.427,
# rev_i: 379, Train error: 0.427,
# rev_i: 380, Train error: 0.427,
# rev_i: 381, Train error: 0.428,
# rev_i: 382, Train error: 0.428,
# rev_i: 383, Train error: 0.428,
# rev_i: 384, Train error: 0.428,
# rev_i: 385, Train error: 0.429,
# rev_i: 386, Train error: 0.429,
# rev_i: 387, Train error: 0.428,
# rev_i: 388, Train error: 0.428,
# rev_i: 389, Train error: 0.428,
# rev_i: 390, Train error: 0.428,
# rev_i: 391, Train error: 0.428,
# rev_i: 392, Train error: 0.427,
# rev_i: 393, Train error: 0.427,
# rev_i: 394, Train error: 0.426,
# rev_i: 395, Train error: 0.426,
# rev_i: 396, Train error: 0.425,
# rev_i: 397, Train error: 0.425,
# rev_i: 398, Train error: 0.424,
# rev_i: 399, Train error: 0.424,
# rev_i: 400, Train error: 0.424,
# rev_i: 401, Train error: 0.424,
# rev_i: 402, Train error: 0.424,
# rev_i: 403, Train error: 0.424,
# rev_i: 404, Train error: 0.423,
# rev_i: 405, Train error: 0.423,
# rev_i: 406, Train error: 0.422,
# rev_i: 407, Train error: 0.422,
# rev_i: 408, Train error: 0.422,
# rev_i: 409, Train error: 0.422,
# rev_i: 410, Train error: 0.421,
# rev_i: 411, Train error: 0.421,
# rev_i: 412, Train error: 0.421,
# rev_i: 413, Train error: 0.421,
# rev_i: 414, Train error: 0.421,
# rev_i: 415, Train error: 0.422,
# rev_i: 416, Train error: 0.421,
# rev_i: 417, Train error: 0.422,
# rev_i: 418, Train error: 0.421,
# rev_i: 419, Train error: 0.421,
# rev_i: 420, Train error: 0.421,
# rev_i: 421, Train error: 0.420,
# rev_i: 422, Train error: 0.420,
# rev_i: 423, Train error: 0.420,
# rev_i: 424, Train error: 0.420,
# rev_i: 425, Train error: 0.420,
# rev_i: 426, Train error: 0.420,
# rev_i: 427, Train error: 0.420,
# rev_i: 428, Train error: 0.420,
# rev_i: 429, Train error: 0.420,
# rev_i: 430, Train error: 0.420,
# rev_i: 431, Train error: 0.420,
# rev_i: 432, Train error: 0.419,
# rev_i: 433, Train error: 0.419,
# rev_i: 434, Train error: 0.419,
# rev_i: 435, Train error: 0.419,
# rev_i: 436, Train error: 0.418,
# rev_i: 437, Train error: 0.418,
# rev_i: 438, Train error: 0.418,
# rev_i: 439, Train error: 0.417,
# rev_i: 440, Train error: 0.417,
# rev_i: 441, Train error: 0.417,
# rev_i: 442, Train error: 0.417,
# rev_i: 443, Train error: 0.416,
# rev_i: 444, Train error: 0.416,
# rev_i: 445, Train error: 0.415,
# rev_i: 446, Train error: 0.415,
# rev_i: 447, Train error: 0.415,
# rev_i: 448, Train error: 0.414,
# rev_i: 449, Train error: 0.414,
# rev_i: 450, Train error: 0.414,
# rev_i: 451, Train error: 0.414,
# rev_i: 452, Train error: 0.413,
# rev_i: 453, Train error: 0.413,
# rev_i: 454, Train error: 0.412,
# rev_i: 455, Train error: 0.412,
# rev_i: 456, Train error: 0.411,
# rev_i: 457, Train error: 0.411,
# rev_i: 458, Train error: 0.411,
# rev_i: 459, Train error: 0.411,
# rev_i: 460, Train error: 0.411,
# rev_i: 461, Train error: 0.411,
# rev_i: 462, Train error: 0.411,
# rev_i: 463, Train error: 0.411,
# rev_i: 464, Train error: 0.411,
# rev_i: 465, Train error: 0.411,
# rev_i: 466, Train error: 0.410,
# rev_i: 467, Train error: 0.410,
# rev_i: 468, Train error: 0.410,
# rev_i: 469, Train error: 0.410,
# rev_i: 470, Train error: 0.410,
# rev_i: 471, Train error: 0.409,
# rev_i: 472, Train error: 0.409,
# rev_i: 473, Train error: 0.409,
# rev_i: 474, Train error: 0.409,
# rev_i: 475, Train error: 0.408,
# rev_i: 476, Train error: 0.407,
# rev_i: 477, Train error: 0.408,
# rev_i: 478, Train error: 0.407,
# rev_i: 479, Train error: 0.407,
# rev_i: 480, Train error: 0.407,
# rev_i: 481, Train error: 0.407,
# rev_i: 482, Train error: 0.407,
# rev_i: 483, Train error: 0.407,
# rev_i: 484, Train error: 0.407,
# rev_i: 485, Train error: 0.407,
# rev_i: 486, Train error: 0.407,
# rev_i: 487, Train error: 0.408,
# rev_i: 488, Train error: 0.407,
# rev_i: 489, Train error: 0.407,
# rev_i: 490, Train error: 0.407,
# rev_i: 491, Train error: 0.407,
# rev_i: 492, Train error: 0.408,
# rev_i: 493, Train error: 0.408,
# rev_i: 494, Train error: 0.408,
# rev_i: 495, Train error: 0.408,
# rev_i: 496, Train error: 0.408,
# rev_i: 497, Train error: 0.408,
# rev_i: 498, Train error: 0.407,
# rev_i: 499, Train error: 0.407,
# rev_i: 500, Train error: 0.407,
# rev_i: 501, Train error: 0.407,
# rev_i: 502, Train error: 0.406,
# rev_i: 503, Train error: 0.406,
# rev_i: 504, Train error: 0.407,
# rev_i: 505, Train error: 0.407,
# rev_i: 506, Train error: 0.406,
# rev_i: 507, Train error: 0.406,
# rev_i: 508, Train error: 0.406,
# rev_i: 509, Train error: 0.406,
# rev_i: 510, Train error: 0.405,
# rev_i: 511, Train error: 0.405,
# rev_i: 512, Train error: 0.405,
# rev_i: 513, Train error: 0.405,
# rev_i: 514, Train error: 0.405,
# rev_i: 515, Train error: 0.404,
# rev_i: 516, Train error: 0.404,
# rev_i: 517, Train error: 0.404,
# rev_i: 518, Train error: 0.403,
# rev_i: 519, Train error: 0.403,
# rev_i: 520, Train error: 0.403,
# rev_i: 521, Train error: 0.403,
# rev_i: 522, Train error: 0.403,
# rev_i: 523, Train error: 0.403,
# rev_i: 524, Train error: 0.403,
# rev_i: 525, Train error: 0.403,
# rev_i: 526, Train error: 0.403,
# rev_i: 527, Train error: 0.403,
# rev_i: 528, Train error: 0.402,
# rev_i: 529, Train error: 0.402,
# rev_i: 530, Train error: 0.402,
# rev_i: 531, Train error: 0.402,
# rev_i: 532, Train error: 0.401,
# rev_i: 533, Train error: 0.401,
# rev_i: 534, Train error: 0.401,
# rev_i: 535, Train error: 0.401,
# rev_i: 536, Train error: 0.400,
# rev_i: 537, Train error: 0.400,
# rev_i: 538, Train error: 0.400,
# rev_i: 539, Train error: 0.400,
# rev_i: 540, Train error: 0.399,
# rev_i: 541, Train error: 0.399,
# rev_i: 542, Train error: 0.399,
# rev_i: 543, Train error: 0.399,
# rev_i: 544, Train error: 0.399,
# rev_i: 545, Train error: 0.399,
# rev_i: 546, Train error: 0.398,
# rev_i: 547, Train error: 0.398,
# rev_i: 548, Train error: 0.398,
# rev_i: 549, Train error: 0.397,
# rev_i: 550, Train error: 0.397,
# rev_i: 551, Train error: 0.397,
# rev_i: 552, Train error: 0.397,
# rev_i: 553, Train error: 0.396,
# rev_i: 554, Train error: 0.396,
# rev_i: 555, Train error: 0.396,
# rev_i: 556, Train error: 0.396,
# rev_i: 557, Train error: 0.395,
# rev_i: 558, Train error: 0.395,
# rev_i: 559, Train error: 0.395,
# rev_i: 560, Train error: 0.394,
# rev_i: 561, Train error: 0.394,
# rev_i: 562, Train error: 0.394,
# rev_i: 563, Train error: 0.394,
# rev_i: 564, Train error: 0.393,
# rev_i: 565, Train error: 0.393,
# rev_i: 566, Train error: 0.393,
# rev_i: 567, Train error: 0.393,
# rev_i: 568, Train error: 0.393,
# rev_i: 569, Train error: 0.393,
# rev_i: 570, Train error: 0.392,
# rev_i: 571, Train error: 0.392,
# rev_i: 572, Train error: 0.392,
# rev_i: 573, Train error: 0.392,
# rev_i: 574, Train error: 0.391,
# rev_i: 575, Train error: 0.391,
# rev_i: 576, Train error: 0.391,
# rev_i: 577, Train error: 0.390,
# rev_i: 578, Train error: 0.390,
# rev_i: 579, Train error: 0.390,
# rev_i: 580, Train error: 0.389,
# rev_i: 581, Train error: 0.389,
# rev_i: 582, Train error: 0.389,
# rev_i: 583, Train error: 0.389,
# rev_i: 584, Train error: 0.389,
# rev_i: 585, Train error: 0.390,
# rev_i: 586, Train error: 0.389,
# rev_i: 587, Train error: 0.390,
# rev_i: 588, Train error: 0.390,
# rev_i: 589, Train error: 0.390,
# rev_i: 590, Train error: 0.390,
# rev_i: 591, Train error: 0.389,
# rev_i: 592, Train error: 0.389,
# rev_i: 593, Train error: 0.389,
# rev_i: 594, Train error: 0.389,
# rev_i: 595, Train error: 0.388,
# rev_i: 596, Train error: 0.388,
# rev_i: 597, Train error: 0.389,
# rev_i: 598, Train error: 0.388,
# rev_i: 599, Train error: 0.388,
# rev_i: 600, Train error: 0.388,
# rev_i: 601, Train error: 0.388,
# rev_i: 602, Train error: 0.388,
# rev_i: 603, Train error: 0.387,
# rev_i: 604, Train error: 0.387,
# rev_i: 605, Train error: 0.386,
# rev_i: 606, Train error: 0.386,
# rev_i: 607, Train error: 0.386,
# rev_i: 608, Train error: 0.386,
# rev_i: 609, Train error: 0.386,
# rev_i: 610, Train error: 0.385,
# rev_i: 611, Train error: 0.385,
# rev_i: 612, Train error: 0.385,
# rev_i: 613, Train error: 0.385,
# rev_i: 614, Train error: 0.385,
# rev_i: 615, Train error: 0.385,
# rev_i: 616, Train error: 0.384,
# rev_i: 617, Train error: 0.384,
# rev_i: 618, Train error: 0.384,
# rev_i: 619, Train error: 0.384,
# rev_i: 620, Train error: 0.383,
# rev_i: 621, Train error: 0.383,
# rev_i: 622, Train error: 0.383,
# rev_i: 623, Train error: 0.382,
# rev_i: 624, Train error: 0.382,
# rev_i: 625, Train error: 0.382,
# rev_i: 626, Train error: 0.382,
# rev_i: 627, Train error: 0.382,
# rev_i: 628, Train error: 0.382,
# rev_i: 629, Train error: 0.382,
# rev_i: 630, Train error: 0.382,
# rev_i: 631, Train error: 0.381,
# rev_i: 632, Train error: 0.381,
# rev_i: 633, Train error: 0.381,
# rev_i: 634, Train error: 0.381,
# rev_i: 635, Train error: 0.381,
# rev_i: 636, Train error: 0.381,
# rev_i: 637, Train error: 0.380,
# rev_i: 638, Train error: 0.380,
# rev_i: 639, Train error: 0.380,
# rev_i: 640, Train error: 0.380,
# rev_i: 641, Train error: 0.380,
# rev_i: 642, Train error: 0.379,
# rev_i: 643, Train error: 0.379,
# rev_i: 644, Train error: 0.379,
# rev_i: 645, Train error: 0.379,
# rev_i: 646, Train error: 0.379,
# rev_i: 647, Train error: 0.379,
# rev_i: 648, Train error: 0.379,
# rev_i: 649, Train error: 0.378,
# rev_i: 650, Train error: 0.379,
# rev_i: 651, Train error: 0.379,
# rev_i: 652, Train error: 0.379,
# rev_i: 653, Train error: 0.378,
# rev_i: 654, Train error: 0.378,
# rev_i: 655, Train error: 0.378,
# rev_i: 656, Train error: 0.378,
# rev_i: 657, Train error: 0.378,
# rev_i: 658, Train error: 0.378,
# rev_i: 659, Train error: 0.378,
# rev_i: 660, Train error: 0.377,
# rev_i: 661, Train error: 0.377,
# rev_i: 662, Train error: 0.377,
# rev_i: 663, Train error: 0.377,
# rev_i: 664, Train error: 0.377,
# rev_i: 665, Train error: 0.377,
# rev_i: 666, Train error: 0.377,
# rev_i: 667, Train error: 0.377,
# rev_i: 668, Train error: 0.376,
# rev_i: 669, Train error: 0.376,
# rev_i: 670, Train error: 0.376,
# rev_i: 671, Train error: 0.376,
# rev_i: 672, Train error: 0.375,
# rev_i: 673, Train error: 0.376,
# rev_i: 674, Train error: 0.375,
# rev_i: 675, Train error: 0.375,
# rev_i: 676, Train error: 0.375,
# rev_i: 677, Train error: 0.375,
# rev_i: 678, Train error: 0.375,
# rev_i: 679, Train error: 0.375,
# rev_i: 680, Train error: 0.375,
# rev_i: 681, Train error: 0.375,
# rev_i: 682, Train error: 0.374,
# rev_i: 683, Train error: 0.374,
# rev_i: 684, Train error: 0.374,
# rev_i: 685, Train error: 0.374,
# rev_i: 686, Train error: 0.374,
# rev_i: 687, Train error: 0.374,
# rev_i: 688, Train error: 0.374,
# rev_i: 689, Train error: 0.373,
# rev_i: 690, Train error: 0.373,
# rev_i: 691, Train error: 0.373,
# rev_i: 692, Train error: 0.373,
# rev_i: 693, Train error: 0.373,
# rev_i: 694, Train error: 0.373,
# rev_i: 695, Train error: 0.373,
# rev_i: 696, Train error: 0.373,
# rev_i: 697, Train error: 0.373,
# rev_i: 698, Train error: 0.373,
# rev_i: 699, Train error: 0.373,
# rev_i: 700, Train error: 0.373,
# rev_i: 701, Train error: 0.372,
# rev_i: 702, Train error: 0.373,
# rev_i: 703, Train error: 0.372,
# rev_i: 704, Train error: 0.372,
# rev_i: 705, Train error: 0.372,
# rev_i: 706, Train error: 0.372,
# rev_i: 707, Train error: 0.372,
# rev_i: 708, Train error: 0.372,
# rev_i: 709, Train error: 0.372,
# rev_i: 710, Train error: 0.372,
# rev_i: 711, Train error: 0.372,
# rev_i: 712, Train error: 0.371,
# rev_i: 713, Train error: 0.371,
# rev_i: 714, Train error: 0.371,
# rev_i: 715, Train error: 0.371,
# rev_i: 716, Train error: 0.371,
# rev_i: 717, Train error: 0.371,
# rev_i: 718, Train error: 0.370,
# rev_i: 719, Train error: 0.370,
# rev_i: 720, Train error: 0.371,
# rev_i: 721, Train error: 0.370,
# rev_i: 722, Train error: 0.370,
# rev_i: 723, Train error: 0.370,
# rev_i: 724, Train error: 0.370,
# rev_i: 725, Train error: 0.370,
# rev_i: 726, Train error: 0.370,
# rev_i: 727, Train error: 0.370,
# rev_i: 728, Train error: 0.370,
# rev_i: 729, Train error: 0.370,
# rev_i: 730, Train error: 0.370,
# rev_i: 731, Train error: 0.370,
# rev_i: 732, Train error: 0.370,
# rev_i: 733, Train error: 0.370,
# rev_i: 734, Train error: 0.369,
# rev_i: 735, Train error: 0.369,
# rev_i: 736, Train error: 0.369,
# rev_i: 737, Train error: 0.369,
# rev_i: 738, Train error: 0.369,
# rev_i: 739, Train error: 0.369,
# rev_i: 740, Train error: 0.369,
# rev_i: 741, Train error: 0.369,
# rev_i: 742, Train error: 0.369,
# rev_i: 743, Train error: 0.369,
# rev_i: 744, Train error: 0.369,
# rev_i: 745, Train error: 0.369,
# rev_i: 746, Train error: 0.369,
# rev_i: 747, Train error: 0.369,
# rev_i: 748, Train error: 0.369,
# rev_i: 749, Train error: 0.369,
# rev_i: 750, Train error: 0.368,
# rev_i: 751, Train error: 0.368,
# rev_i: 752, Train error: 0.368,
# rev_i: 753, Train error: 0.369,
# rev_i: 754, Train error: 0.369,
# rev_i: 755, Train error: 0.369,
# rev_i: 756, Train error: 0.368,
# rev_i: 757, Train error: 0.368,
# rev_i: 758, Train error: 0.368,
# rev_i: 759, Train error: 0.368,
# rev_i: 760, Train error: 0.368,
# rev_i: 761, Train error: 0.368,
# rev_i: 762, Train error: 0.368,
# rev_i: 763, Train error: 0.368,
# rev_i: 764, Train error: 0.368,
# rev_i: 765, Train error: 0.368,
# rev_i: 766, Train error: 0.368,
# rev_i: 767, Train error: 0.368,
# rev_i: 768, Train error: 0.367,
# rev_i: 769, Train error: 0.367,
# rev_i: 770, Train error: 0.367,
# rev_i: 771, Train error: 0.367,
# rev_i: 772, Train error: 0.367,
# rev_i: 773, Train error: 0.367,
# rev_i: 774, Train error: 0.367,
# rev_i: 775, Train error: 0.367,
# rev_i: 776, Train error: 0.367,
# rev_i: 777, Train error: 0.366,
# rev_i: 778, Train error: 0.366,
# rev_i: 779, Train error: 0.366,
# rev_i: 780, Train error: 0.366,
# rev_i: 781, Train error: 0.366,
# rev_i: 782, Train error: 0.366,
# rev_i: 783, Train error: 0.366,
# rev_i: 784, Train error: 0.366,
# rev_i: 785, Train error: 0.366,
# rev_i: 786, Train error: 0.365,
# rev_i: 787, Train error: 0.365,
# rev_i: 788, Train error: 0.365,
# rev_i: 789, Train error: 0.365,
# rev_i: 790, Train error: 0.365,
# rev_i: 791, Train error: 0.365,
# rev_i: 792, Train error: 0.365,
# rev_i: 793, Train error: 0.364,
# rev_i: 794, Train error: 0.364,
# rev_i: 795, Train error: 0.364,
# rev_i: 796, Train error: 0.364,
# rev_i: 797, Train error: 0.363,
# rev_i: 798, Train error: 0.363,
# rev_i: 799, Train error: 0.363,
# rev_i: 800, Train error: 0.363,
# rev_i: 801, Train error: 0.363,
# rev_i: 802, Train error: 0.362,
# rev_i: 803, Train error: 0.362,
# rev_i: 804, Train error: 0.362,
# rev_i: 805, Train error: 0.362,
# rev_i: 806, Train error: 0.362,
# rev_i: 807, Train error: 0.362,
# rev_i: 808, Train error: 0.362,
# rev_i: 809, Train error: 0.361,
# rev_i: 810, Train error: 0.361,
# rev_i: 811, Train error: 0.361,
# rev_i: 812, Train error: 0.361,
# rev_i: 813, Train error: 0.361,
# rev_i: 814, Train error: 0.361,
# rev_i: 815, Train error: 0.360,
# rev_i: 816, Train error: 0.360,
# rev_i: 817, Train error: 0.360,
# rev_i: 818, Train error: 0.360,
# rev_i: 819, Train error: 0.360,
# rev_i: 820, Train error: 0.360,
# rev_i: 821, Train error: 0.360,
# rev_i: 822, Train error: 0.360,
# rev_i: 823, Train error: 0.360,
# rev_i: 824, Train error: 0.359,
# rev_i: 825, Train error: 0.360,
# rev_i: 826, Train error: 0.359,
# rev_i: 827, Train error: 0.359,
# rev_i: 828, Train error: 0.359,
# rev_i: 829, Train error: 0.360,
# rev_i: 830, Train error: 0.360,
# rev_i: 831, Train error: 0.359,
# rev_i: 832, Train error: 0.360,
# rev_i: 833, Train error: 0.359,
# rev_i: 834, Train error: 0.359,
# rev_i: 835, Train error: 0.359,
# rev_i: 836, Train error: 0.359,
# rev_i: 837, Train error: 0.359,
# rev_i: 838, Train error: 0.359,
# rev_i: 839, Train error: 0.358,
# rev_i: 840, Train error: 0.358,
# rev_i: 841, Train error: 0.358,
# rev_i: 842, Train error: 0.358,
# rev_i: 843, Train error: 0.358,
# rev_i: 844, Train error: 0.358,
# rev_i: 845, Train error: 0.358,
# rev_i: 846, Train error: 0.358,
# rev_i: 847, Train error: 0.358,
# rev_i: 848, Train error: 0.358,
# rev_i: 849, Train error: 0.358,
# rev_i: 850, Train error: 0.358,
# rev_i: 851, Train error: 0.357,
# rev_i: 852, Train error: 0.357,
# rev_i: 853, Train error: 0.357,
# rev_i: 854, Train error: 0.357,
# rev_i: 855, Train error: 0.357,
# rev_i: 856, Train error: 0.357,
# rev_i: 857, Train error: 0.357,
# rev_i: 858, Train error: 0.357,
# rev_i: 859, Train error: 0.357,
# rev_i: 860, Train error: 0.357,
# rev_i: 861, Train error: 0.357,
# rev_i: 862, Train error: 0.357,
# rev_i: 863, Train error: 0.357,
# rev_i: 864, Train error: 0.356,
# rev_i: 865, Train error: 0.356,
# rev_i: 866, Train error: 0.356,
# rev_i: 867, Train error: 0.356,
# rev_i: 868, Train error: 0.356,
# rev_i: 869, Train error: 0.356,
# rev_i: 870, Train error: 0.356,
# rev_i: 871, Train error: 0.355,
# rev_i: 872, Train error: 0.355,
# rev_i: 873, Train error: 0.355,
# rev_i: 874, Train error: 0.356,
# rev_i: 875, Train error: 0.356,
# rev_i: 876, Train error: 0.356,
# rev_i: 877, Train error: 0.356,
# rev_i: 878, Train error: 0.356,
# rev_i: 879, Train error: 0.356,
# rev_i: 880, Train error: 0.356,
# rev_i: 881, Train error: 0.356,
# rev_i: 882, Train error: 0.356,
# rev_i: 883, Train error: 0.355,
# rev_i: 884, Train error: 0.355,
# rev_i: 885, Train error: 0.355,
# rev_i: 886, Train error: 0.355,
# rev_i: 887, Train error: 0.355,
# rev_i: 888, Train error: 0.355,
# rev_i: 889, Train error: 0.355,
# rev_i: 890, Train error: 0.355,
# rev_i: 891, Train error: 0.355,
# rev_i: 892, Train error: 0.355,
# rev_i: 893, Train error: 0.355,
# rev_i: 894, Train error: 0.355,
# rev_i: 895, Train error: 0.355,
# rev_i: 896, Train error: 0.355,
# rev_i: 897, Train error: 0.355,
# rev_i: 898, Train error: 0.355,
# rev_i: 899, Train error: 0.355,
# rev_i: 900, Train error: 0.355,
# rev_i: 901, Train error: 0.355,
# rev_i: 902, Train error: 0.355,
# rev_i: 903, Train error: 0.355,
# rev_i: 904, Train error: 0.355,
# rev_i: 905, Train error: 0.354,
# rev_i: 906, Train error: 0.354,
# rev_i: 907, Train error: 0.354,
# rev_i: 908, Train error: 0.354,
# rev_i: 909, Train error: 0.354,
# rev_i: 910, Train error: 0.354,
# rev_i: 911, Train error: 0.354,
# rev_i: 912, Train error: 0.354,
# rev_i: 913, Train error: 0.353,
# rev_i: 914, Train error: 0.353,
# rev_i: 915, Train error: 0.353,
# rev_i: 916, Train error: 0.353,
# rev_i: 917, Train error: 0.353,
# rev_i: 918, Train error: 0.353,
# rev_i: 919, Train error: 0.353,
# rev_i: 920, Train error: 0.353,
# rev_i: 921, Train error: 0.353,
# rev_i: 922, Train error: 0.353,
# rev_i: 923, Train error: 0.353,
# rev_i: 924, Train error: 0.352,
# rev_i: 925, Train error: 0.352,
# rev_i: 926, Train error: 0.352,
# rev_i: 927, Train error: 0.352,
# rev_i: 928, Train error: 0.352,
# rev_i: 929, Train error: 0.352,
# rev_i: 930, Train error: 0.352,
# rev_i: 931, Train error: 0.352,
# rev_i: 932, Train error: 0.352,
# rev_i: 933, Train error: 0.352,
# rev_i: 934, Train error: 0.352,
# rev_i: 935, Train error: 0.352,
# rev_i: 936, Train error: 0.352,
# rev_i: 937, Train error: 0.352,
# rev_i: 938, Train error: 0.352,
# rev_i: 939, Train error: 0.352,
# rev_i: 940, Train error: 0.352,
# rev_i: 941, Train error: 0.352,
# rev_i: 942, Train error: 0.351,
# rev_i: 943, Train error: 0.351,
# rev_i: 944, Train error: 0.351,
# rev_i: 945, Train error: 0.351,
# rev_i: 946, Train error: 0.351,
# rev_i: 947, Train error: 0.351,
# rev_i: 948, Train error: 0.351,
# rev_i: 949, Train error: 0.351,
# rev_i: 950, Train error: 0.351,
# rev_i: 951, Train error: 0.351,
# rev_i: 952, Train error: 0.350,
# rev_i: 953, Train error: 0.350,
# rev_i: 954, Train error: 0.350,
# rev_i: 955, Train error: 0.350,
# rev_i: 956, Train error: 0.350,
# rev_i: 957, Train error: 0.350,
# rev_i: 958, Train error: 0.350,
# rev_i: 959, Train error: 0.350,
# rev_i: 960, Train error: 0.349,
# rev_i: 961, Train error: 0.349,
# rev_i: 962, Train error: 0.349,
# rev_i: 963, Train error: 0.349,
# rev_i: 964, Train error: 0.349,
# rev_i: 965, Train error: 0.349,
# rev_i: 966, Train error: 0.349,
# rev_i: 967, Train error: 0.349,
# rev_i: 968, Train error: 0.349,
# rev_i: 969, Train error: 0.349,
# rev_i: 970, Train error: 0.349,
# rev_i: 971, Train error: 0.349,
# rev_i: 972, Train error: 0.349,
# rev_i: 973, Train error: 0.349,
# rev_i: 974, Train error: 0.349,
# rev_i: 975, Train error: 0.349,
# rev_i: 976, Train error: 0.348,
# rev_i: 977, Train error: 0.348,
# rev_i: 978, Train error: 0.348,
# rev_i: 979, Train error: 0.348,
# rev_i: 980, Train error: 0.348,
# rev_i: 981, Train error: 0.348,
# rev_i: 982, Train error: 0.347,
# rev_i: 983, Train error: 0.347,
# rev_i: 984, Train error: 0.347,
# rev_i: 985, Train error: 0.347,
# rev_i: 986, Train error: 0.347,
# rev_i: 987, Train error: 0.347,
# rev_i: 988, Train error: 0.347,
# rev_i: 989, Train error: 0.347,
# rev_i: 990, Train error: 0.346,
# rev_i: 991, Train error: 0.347,
# rev_i: 992, Train error: 0.346,
# rev_i: 993, Train error: 0.346,
# rev_i: 994, Train error: 0.346,
# rev_i: 995, Train error: 0.346,
# rev_i: 996, Train error: 0.346,
# rev_i: 997, Train error: 0.346,
# rev_i: 998, Train error: 0.346,
# rev_i: 999, Train error: 0.346,
# rev_i: 1000, Train error: 0.345,
# rev_i: 1001, Train error: 0.345,
# rev_i: 1002, Train error: 0.345,
# rev_i: 1003, Train error: 0.345,
# rev_i: 1004, Train error: 0.345,
# rev_i: 1005, Train error: 0.345,
# rev_i: 1006, Train error: 0.345,
# rev_i: 1007, Train error: 0.345,
# rev_i: 1008, Train error: 0.344,
# rev_i: 1009, Train error: 0.344,
# rev_i: 1010, Train error: 0.344,
# rev_i: 1011, Train error: 0.344,
# rev_i: 1012, Train error: 0.344,
# rev_i: 1013, Train error: 0.344,
# rev_i: 1014, Train error: 0.344,
# rev_i: 1015, Train error: 0.344,
# rev_i: 1016, Train error: 0.344,
# rev_i: 1017, Train error: 0.344,
# rev_i: 1018, Train error: 0.344,
# rev_i: 1019, Train error: 0.344,
# rev_i: 1020, Train error: 0.344,
# rev_i: 1021, Train error: 0.343,
# rev_i: 1022, Train error: 0.343,
# rev_i: 1023, Train error: 0.343,
# rev_i: 1024, Train error: 0.343,
# rev_i: 1025, Train error: 0.343,
# rev_i: 1026, Train error: 0.343,
# rev_i: 1027, Train error: 0.342,
# rev_i: 1028, Train error: 0.342,
# rev_i: 1029, Train error: 0.342,
# rev_i: 1030, Train error: 0.342,
# rev_i: 1031, Train error: 0.342,
# rev_i: 1032, Train error: 0.342,
# rev_i: 1033, Train error: 0.342,
# rev_i: 1034, Train error: 0.342,
# rev_i: 1035, Train error: 0.342,
# rev_i: 1036, Train error: 0.342,
# rev_i: 1037, Train error: 0.342,
# rev_i: 1038, Train error: 0.342,
# rev_i: 1039, Train error: 0.342,
# rev_i: 1040, Train error: 0.341,
# rev_i: 1041, Train error: 0.341,
# rev_i: 1042, Train error: 0.341,
# rev_i: 1043, Train error: 0.341,
# rev_i: 1044, Train error: 0.341,
# rev_i: 1045, Train error: 0.341,
# rev_i: 1046, Train error: 0.341,
# rev_i: 1047, Train error: 0.341,
# rev_i: 1048, Train error: 0.341,
# rev_i: 1049, Train error: 0.340,
# rev_i: 1050, Train error: 0.340,
# rev_i: 1051, Train error: 0.340,
# rev_i: 1052, Train error: 0.340,
# rev_i: 1053, Train error: 0.340,
# rev_i: 1054, Train error: 0.340,
# rev_i: 1055, Train error: 0.340,
# rev_i: 1056, Train error: 0.340,
# rev_i: 1057, Train error: 0.339,
# rev_i: 1058, Train error: 0.339,
# rev_i: 1059, Train error: 0.339,
# rev_i: 1060, Train error: 0.339,
# rev_i: 1061, Train error: 0.339,
# rev_i: 1062, Train error: 0.339,
# rev_i: 1063, Train error: 0.339,
# rev_i: 1064, Train error: 0.339,
# rev_i: 1065, Train error: 0.339,
# rev_i: 1066, Train error: 0.338,
# rev_i: 1067, Train error: 0.338,
# rev_i: 1068, Train error: 0.338,
# rev_i: 1069, Train error: 0.338,
# rev_i: 1070, Train error: 0.338,
# rev_i: 1071, Train error: 0.338,
# rev_i: 1072, Train error: 0.338,
# rev_i: 1073, Train error: 0.338,
# rev_i: 1074, Train error: 0.338,
# rev_i: 1075, Train error: 0.338,
# rev_i: 1076, Train error: 0.338,
# rev_i: 1077, Train error: 0.338,
# rev_i: 1078, Train error: 0.338,
# rev_i: 1079, Train error: 0.338,
# rev_i: 1080, Train error: 0.338,
# rev_i: 1081, Train error: 0.338,
# rev_i: 1082, Train error: 0.337,
# rev_i: 1083, Train error: 0.337,
# rev_i: 1084, Train error: 0.337,
# rev_i: 1085, Train error: 0.337,
# rev_i: 1086, Train error: 0.337,
# rev_i: 1087, Train error: 0.337,
# rev_i: 1088, Train error: 0.337,
# rev_i: 1089, Train error: 0.337,
# rev_i: 1090, Train error: 0.337,
# rev_i: 1091, Train error: 0.337,
# rev_i: 1092, Train error: 0.337,
# rev_i: 1093, Train error: 0.337,
# rev_i: 1094, Train error: 0.337,
# rev_i: 1095, Train error: 0.336,
# rev_i: 1096, Train error: 0.336,
# rev_i: 1097, Train error: 0.336,
# rev_i: 1098, Train error: 0.336,
# rev_i: 1099, Train error: 0.336,
# rev_i: 1100, Train error: 0.336,
# rev_i: 1101, Train error: 0.336,
# rev_i: 1102, Train error: 0.336,
# rev_i: 1103, Train error: 0.336,
# rev_i: 1104, Train error: 0.336,
# rev_i: 1105, Train error: 0.336,
# rev_i: 1106, Train error: 0.336,
# rev_i: 1107, Train error: 0.336,
# rev_i: 1108, Train error: 0.336,
# rev_i: 1109, Train error: 0.336,
# rev_i: 1110, Train error: 0.336,
# rev_i: 1111, Train error: 0.336,
# rev_i: 1112, Train error: 0.336,
# rev_i: 1113, Train error: 0.335,
# rev_i: 1114, Train error: 0.335,
# rev_i: 1115, Train error: 0.335,
# rev_i: 1116, Train error: 0.335,
# rev_i: 1117, Train error: 0.335,
# rev_i: 1118, Train error: 0.335,
# rev_i: 1119, Train error: 0.335,
# rev_i: 1120, Train error: 0.334,
# rev_i: 1121, Train error: 0.334,
# rev_i: 1122, Train error: 0.334,
# rev_i: 1123, Train error: 0.334,
# rev_i: 1124, Train error: 0.334,
# rev_i: 1125, Train error: 0.334,
# rev_i: 1126, Train error: 0.334,
# rev_i: 1127, Train error: 0.333,
# rev_i: 1128, Train error: 0.333,
# rev_i: 1129, Train error: 0.333,
# rev_i: 1130, Train error: 0.333,
# rev_i: 1131, Train error: 0.333,
# rev_i: 1132, Train error: 0.333,
# rev_i: 1133, Train error: 0.333,
# rev_i: 1134, Train error: 0.333,
# rev_i: 1135, Train error: 0.333,
# rev_i: 1136, Train error: 0.333,
# rev_i: 1137, Train error: 0.333,
# rev_i: 1138, Train error: 0.333,
# rev_i: 1139, Train error: 0.333,
# rev_i: 1140, Train error: 0.333,
# rev_i: 1141, Train error: 0.333,
# rev_i: 1142, Train error: 0.332,
# rev_i: 1143, Train error: 0.332,
# rev_i: 1144, Train error: 0.332,
# rev_i: 1145, Train error: 0.332,
# rev_i: 1146, Train error: 0.332,
# rev_i: 1147, Train error: 0.332,
# rev_i: 1148, Train error: 0.332,
# rev_i: 1149, Train error: 0.332,
# rev_i: 1150, Train error: 0.332,
# rev_i: 1151, Train error: 0.332,
# rev_i: 1152, Train error: 0.332,
# rev_i: 1153, Train error: 0.332,
# rev_i: 1154, Train error: 0.332,
# rev_i: 1155, Train error: 0.332,
# rev_i: 1156, Train error: 0.332,
# rev_i: 1157, Train error: 0.332,
# rev_i: 1158, Train error: 0.332,
# rev_i: 1159, Train error: 0.332,
# rev_i: 1160, Train error: 0.332,
# rev_i: 1161, Train error: 0.332,
# rev_i: 1162, Train error: 0.332,
# rev_i: 1163, Train error: 0.331,
# rev_i: 1164, Train error: 0.331,
# rev_i: 1165, Train error: 0.331,
# rev_i: 1166, Train error: 0.331,
# rev_i: 1167, Train error: 0.331,
# rev_i: 1168, Train error: 0.331,
# rev_i: 1169, Train error: 0.331,
# rev_i: 1170, Train error: 0.331,
# rev_i: 1171, Train error: 0.331,
# rev_i: 1172, Train error: 0.331,
# rev_i: 1173, Train error: 0.331,
# rev_i: 1174, Train error: 0.331,
# rev_i: 1175, Train error: 0.331,
# rev_i: 1176, Train error: 0.331,
# rev_i: 1177, Train error: 0.331,
# rev_i: 1178, Train error: 0.331,
# rev_i: 1179, Train error: 0.331,
# rev_i: 1180, Train error: 0.331,
# rev_i: 1181, Train error: 0.331,
# rev_i: 1182, Train error: 0.331,
# rev_i: 1183, Train error: 0.331,
# rev_i: 1184, Train error: 0.331,
# rev_i: 1185, Train error: 0.331,
# rev_i: 1186, Train error: 0.331,
# rev_i: 1187, Train error: 0.331,
# rev_i: 1188, Train error: 0.330,
# rev_i: 1189, Train error: 0.330,
# rev_i: 1190, Train error: 0.330,
# rev_i: 1191, Train error: 0.331,
# rev_i: 1192, Train error: 0.330,
# rev_i: 1193, Train error: 0.331,
# rev_i: 1194, Train error: 0.330,
# rev_i: 1195, Train error: 0.330,
# rev_i: 1196, Train error: 0.330,
# rev_i: 1197, Train error: 0.330,
# rev_i: 1198, Train error: 0.330,
# rev_i: 1199, Train error: 0.330,
# rev_i: 1200, Train error: 0.330,
# rev_i: 1201, Train error: 0.330,
# rev_i: 1202, Train error: 0.330,
# rev_i: 1203, Train error: 0.330,
# rev_i: 1204, Train error: 0.330,
# rev_i: 1205, Train error: 0.330,
# rev_i: 1206, Train error: 0.330,
# rev_i: 1207, Train error: 0.330,
# rev_i: 1208, Train error: 0.330,
# rev_i: 1209, Train error: 0.330,
# rev_i: 1210, Train error: 0.330,
# rev_i: 1211, Train error: 0.330,
# rev_i: 1212, Train error: 0.330,
# rev_i: 1213, Train error: 0.329,
# rev_i: 1214, Train error: 0.329,
# rev_i: 1215, Train error: 0.329,
# rev_i: 1216, Train error: 0.329,
# rev_i: 1217, Train error: 0.329,
# rev_i: 1218, Train error: 0.329,
# rev_i: 1219, Train error: 0.329,
# rev_i: 1220, Train error: 0.329,
# rev_i: 1221, Train error: 0.329,
# rev_i: 1222, Train error: 0.329,
# rev_i: 1223, Train error: 0.329,
# rev_i: 1224, Train error: 0.329,
# rev_i: 1225, Train error: 0.329,
# rev_i: 1226, Train error: 0.329,
# rev_i: 1227, Train error: 0.329,
# rev_i: 1228, Train error: 0.329,
# rev_i: 1229, Train error: 0.329,
# rev_i: 1230, Train error: 0.328,
# rev_i: 1231, Train error: 0.329,
# rev_i: 1232, Train error: 0.328,
# rev_i: 1233, Train error: 0.328,
# rev_i: 1234, Train error: 0.328,
# rev_i: 1235, Train error: 0.328,
# rev_i: 1236, Train error: 0.328,
# rev_i: 1237, Train error: 0.328,
# rev_i: 1238, Train error: 0.328,
# rev_i: 1239, Train error: 0.328,
# rev_i: 1240, Train error: 0.328,
# rev_i: 1241, Train error: 0.328,
# rev_i: 1242, Train error: 0.327,
# rev_i: 1243, Train error: 0.327,
# rev_i: 1244, Train error: 0.327,
# rev_i: 1245, Train error: 0.327,
# rev_i: 1246, Train error: 0.327,
# rev_i: 1247, Train error: 0.327,
# rev_i: 1248, Train error: 0.327,
# rev_i: 1249, Train error: 0.327,
# rev_i: 1250, Train error: 0.327,
# rev_i: 1251, Train error: 0.327,
# rev_i: 1252, Train error: 0.327,
# rev_i: 1253, Train error: 0.327,
# rev_i: 1254, Train error: 0.327,
# rev_i: 1255, Train error: 0.327,
# rev_i: 1256, Train error: 0.327,
# rev_i: 1257, Train error: 0.327,
# rev_i: 1258, Train error: 0.327,
# rev_i: 1259, Train error: 0.327,
# rev_i: 1260, Train error: 0.327,
# rev_i: 1261, Train error: 0.327,
# rev_i: 1262, Train error: 0.327,
# rev_i: 1263, Train error: 0.326,
# rev_i: 1264, Train error: 0.326,
# rev_i: 1265, Train error: 0.326,
# rev_i: 1266, Train error: 0.326,
# rev_i: 1267, Train error: 0.326,
# rev_i: 1268, Train error: 0.326,
# rev_i: 1269, Train error: 0.326,
# rev_i: 1270, Train error: 0.326,
# rev_i: 1271, Train error: 0.326,
# rev_i: 1272, Train error: 0.326,
# rev_i: 1273, Train error: 0.326,
# rev_i: 1274, Train error: 0.326,
# rev_i: 1275, Train error: 0.326,
# rev_i: 1276, Train error: 0.326,
# rev_i: 1277, Train error: 0.326,
# rev_i: 1278, Train error: 0.326,
# rev_i: 1279, Train error: 0.325,
# rev_i: 1280, Train error: 0.325,
# rev_i: 1281, Train error: 0.325,
# rev_i: 1282, Train error: 0.325,
# rev_i: 1283, Train error: 0.325,
# rev_i: 1284, Train error: 0.325,
# rev_i: 1285, Train error: 0.325,
# rev_i: 1286, Train error: 0.325,
# rev_i: 1287, Train error: 0.325,
# rev_i: 1288, Train error: 0.325,
# rev_i: 1289, Train error: 0.325,
# rev_i: 1290, Train error: 0.325,
# rev_i: 1291, Train error: 0.325,
# rev_i: 1292, Train error: 0.325,
# rev_i: 1293, Train error: 0.325,
# rev_i: 1294, Train error: 0.325,
# rev_i: 1295, Train error: 0.325,
# rev_i: 1296, Train error: 0.325,
# rev_i: 1297, Train error: 0.325,
# rev_i: 1298, Train error: 0.325,
# rev_i: 1299, Train error: 0.325,
# rev_i: 1300, Train error: 0.325,
# rev_i: 1301, Train error: 0.325,
# rev_i: 1302, Train error: 0.325,
# rev_i: 1303, Train error: 0.325,
# rev_i: 1304, Train error: 0.325,
# rev_i: 1305, Train error: 0.325,
# rev_i: 1306, Train error: 0.325,
# rev_i: 1307, Train error: 0.325,
# rev_i: 1308, Train error: 0.325,
# rev_i: 1309, Train error: 0.325,
# rev_i: 1310, Train error: 0.325,
# rev_i: 1311, Train error: 0.325,
# rev_i: 1312, Train error: 0.325,
# rev_i: 1313, Train error: 0.325,
# rev_i: 1314, Train error: 0.325,
# rev_i: 1315, Train error: 0.325,
# rev_i: 1316, Train error: 0.325,
# rev_i: 1317, Train error: 0.325,
# rev_i: 1318, Train error: 0.325,
# rev_i: 1319, Train error: 0.325,
# rev_i: 1320, Train error: 0.325,
# rev_i: 1321, Train error: 0.325,
# rev_i: 1322, Train error: 0.324,
# rev_i: 1323, Train error: 0.324,
# rev_i: 1324, Train error: 0.324,
# rev_i: 1325, Train error: 0.324,
# rev_i: 1326, Train error: 0.324,
# rev_i: 1327, Train error: 0.324,
# rev_i: 1328, Train error: 0.324,
# rev_i: 1329, Train error: 0.324,
# rev_i: 1330, Train error: 0.324,
# rev_i: 1331, Train error: 0.324,
# rev_i: 1332, Train error: 0.324,
# rev_i: 1333, Train error: 0.324,
# rev_i: 1334, Train error: 0.324,
# rev_i: 1335, Train error: 0.324,
# rev_i: 1336, Train error: 0.324,
# rev_i: 1337, Train error: 0.324,
# rev_i: 1338, Train error: 0.324,
# rev_i: 1339, Train error: 0.324,
# rev_i: 1340, Train error: 0.324,
# rev_i: 1341, Train error: 0.324,
# rev_i: 1342, Train error: 0.324,
# rev_i: 1343, Train error: 0.323,
# rev_i: 1344, Train error: 0.324,
# rev_i: 1345, Train error: 0.324,
# rev_i: 1346, Train error: 0.324,
# rev_i: 1347, Train error: 0.324,
# rev_i: 1348, Train error: 0.324,
# rev_i: 1349, Train error: 0.323,
# rev_i: 1350, Train error: 0.323,
# rev_i: 1351, Train error: 0.323,
# rev_i: 1352, Train error: 0.323,
# rev_i: 1353, Train error: 0.323,
# rev_i: 1354, Train error: 0.323,
# rev_i: 1355, Train error: 0.323,
# rev_i: 1356, Train error: 0.323,
# rev_i: 1357, Train error: 0.323,
# rev_i: 1358, Train error: 0.323,
# rev_i: 1359, Train error: 0.323,
# rev_i: 1360, Train error: 0.323,
# rev_i: 1361, Train error: 0.323,
# rev_i: 1362, Train error: 0.323,
# rev_i: 1363, Train error: 0.323,
# rev_i: 1364, Train error: 0.323,
# rev_i: 1365, Train error: 0.323,
# rev_i: 1366, Train error: 0.323,
# rev_i: 1367, Train error: 0.323,
# rev_i: 1368, Train error: 0.323,
# rev_i: 1369, Train error: 0.323,
# rev_i: 1370, Train error: 0.323,
# rev_i: 1371, Train error: 0.323,
# rev_i: 1372, Train error: 0.323,
# rev_i: 1373, Train error: 0.323,
# rev_i: 1374, Train error: 0.323,
# rev_i: 1375, Train error: 0.323,
# rev_i: 1376, Train error: 0.323,
# rev_i: 1377, Train error: 0.323,
# rev_i: 1378, Train error: 0.323,
# rev_i: 1379, Train error: 0.323,
# rev_i: 1380, Train error: 0.323,
# rev_i: 1381, Train error: 0.323,
# rev_i: 1382, Train error: 0.323,
# rev_i: 1383, Train error: 0.323,
# rev_i: 1384, Train error: 0.323,
# rev_i: 1385, Train error: 0.323,
# rev_i: 1386, Train error: 0.323,
# rev_i: 1387, Train error: 0.323,
# rev_i: 1388, Train error: 0.323,
# rev_i: 1389, Train error: 0.323,
# rev_i: 1390, Train error: 0.323,
# rev_i: 1391, Train error: 0.323,
# rev_i: 1392, Train error: 0.323,
# rev_i: 1393, Train error: 0.323,
# rev_i: 1394, Train error: 0.323,
# rev_i: 1395, Train error: 0.322,
# rev_i: 1396, Train error: 0.322,
# rev_i: 1397, Train error: 0.323,
# rev_i: 1398, Train error: 0.322,
# rev_i: 1399, Train error: 0.322,
# rev_i: 1400, Train error: 0.322,
# rev_i: 1401, Train error: 0.322,
# rev_i: 1402, Train error: 0.322,
# rev_i: 1403, Train error: 0.322,
# rev_i: 1404, Train error: 0.322,
# rev_i: 1405, Train error: 0.322,
# rev_i: 1406, Train error: 0.322,
# rev_i: 1407, Train error: 0.322,
# rev_i: 1408, Train error: 0.322,
# rev_i: 1409, Train error: 0.322,
# rev_i: 1410, Train error: 0.322,
# rev_i: 1411, Train error: 0.322,
# rev_i: 1412, Train error: 0.322,
# rev_i: 1413, Train error: 0.322,
# rev_i: 1414, Train error: 0.322,
# rev_i: 1415, Train error: 0.322,
# rev_i: 1416, Train error: 0.322,
# rev_i: 1417, Train error: 0.322,
# rev_i: 1418, Train error: 0.322,
# rev_i: 1419, Train error: 0.322,
# rev_i: 1420, Train error: 0.322,
# rev_i: 1421, Train error: 0.322,
# rev_i: 1422, Train error: 0.322,
# rev_i: 1423, Train error: 0.322,
# rev_i: 1424, Train error: 0.322,
# rev_i: 1425, Train error: 0.321,
# rev_i: 1426, Train error: 0.321,
# rev_i: 1427, Train error: 0.321,
# rev_i: 1428, Train error: 0.321,
# rev_i: 1429, Train error: 0.321,
# rev_i: 1430, Train error: 0.321,
# rev_i: 1431, Train error: 0.321,
# rev_i: 1432, Train error: 0.322,
# rev_i: 1433, Train error: 0.321,
# rev_i: 1434, Train error: 0.321,
# rev_i: 1435, Train error: 0.321,
# rev_i: 1436, Train error: 0.321,
# rev_i: 1437, Train error: 0.321,
# rev_i: 1438, Train error: 0.321,
# rev_i: 1439, Train error: 0.321,
# rev_i: 1440, Train error: 0.321,
# rev_i: 1441, Train error: 0.321,
# rev_i: 1442, Train error: 0.321,
# rev_i: 1443, Train error: 0.321,
# rev_i: 1444, Train error: 0.321,
# rev_i: 1445, Train error: 0.321,
# rev_i: 1446, Train error: 0.321,
# rev_i: 1447, Train error: 0.321,
# rev_i: 1448, Train error: 0.321,
# rev_i: 1449, Train error: 0.321,
# rev_i: 1450, Train error: 0.321,
# rev_i: 1451, Train error: 0.321,
# rev_i: 1452, Train error: 0.321,
# rev_i: 1453, Train error: 0.321,
# rev_i: 1454, Train error: 0.321,
# rev_i: 1455, Train error: 0.321,
# rev_i: 1456, Train error: 0.321,
# rev_i: 1457, Train error: 0.321,
# rev_i: 1458, Train error: 0.321,
# rev_i: 1459, Train error: 0.321,
# rev_i: 1460, Train error: 0.320,
# rev_i: 1461, Train error: 0.320,
# rev_i: 1462, Train error: 0.320,
# rev_i: 1463, Train error: 0.320,
# rev_i: 1464, Train error: 0.320,
# rev_i: 1465, Train error: 0.320,
# rev_i: 1466, Train error: 0.320,
# rev_i: 1467, Train error: 0.320,
# rev_i: 1468, Train error: 0.320,
# rev_i: 1469, Train error: 0.320,
# rev_i: 1470, Train error: 0.320,
# rev_i: 1471, Train error: 0.320,
# rev_i: 1472, Train error: 0.320,
# rev_i: 1473, Train error: 0.320,
# rev_i: 1474, Train error: 0.320,
# rev_i: 1475, Train error: 0.320,
# rev_i: 1476, Train error: 0.320,
# rev_i: 1477, Train error: 0.320,
# rev_i: 1478, Train error: 0.320,
# rev_i: 1479, Train error: 0.320,
# rev_i: 1480, Train error: 0.320,
# rev_i: 1481, Train error: 0.319,
# rev_i: 1482, Train error: 0.319,
# rev_i: 1483, Train error: 0.319,
# rev_i: 1484, Train error: 0.319,
# rev_i: 1485, Train error: 0.319,
# rev_i: 1486, Train error: 0.319,
# rev_i: 1487, Train error: 0.319,
# ...
# rev_i: 24530, Train error: 0.224,
# rev_i: 24531, Train error: 0.224,
# rev_i: 24532, Train error: 0.224,
# rev_i: 24533, Train error: 0.224,
# rev_i: 24534, Train error: 0.224,
# rev_i: 24535, Train error: 0.224,
# rev_i: 24536, Train error: 0.224,
# rev_i: 24537, Train error: 0.224,
# rev_i: 24538, Train error: 0.224,
# rev_i: 24539, Train error: 0.224,
# rev_i: 24540, Train error: 0.224,
# rev_i: 24541, Train error: 0.224,
# rev_i: 24542, Train error: 0.224,
# rev_i: 24543, Train error: 0.224,
# rev_i: 24544, Train error: 0.224,
# rev_i: 24545, Train error: 0.224,
# rev_i: 24546, Train error: 0.224,
# rev_i: 24547, Train error: 0.224,
# rev_i: 24548, Train error: 0.224,
# rev_i: 24549, Train error: 0.224,
# rev_i: 24550, Train error: 0.224,
# rev_i: 24551, Train error: 0.224,
# rev_i: 24552, Train error: 0.224,
# rev_i: 24553, Train error: 0.224,
# rev_i: 24554, Train error: 0.224,
# rev_i: 24555, Train error: 0.224,
# rev_i: 24556, Train error: 0.224,
# rev_i: 24557, Train error: 0.224,
# rev_i: 24558, Train error: 0.224,
# rev_i: 24559, Train error: 0.224,
# rev_i: 24560, Train error: 0.224,
# rev_i: 24561, Train error: 0.224,
# rev_i: 24562, Train error: 0.224,
# rev_i: 24563, Train error: 0.224,
# rev_i: 24564, Train error: 0.224,
# rev_i: 24565, Train error: 0.224,
# rev_i: 24566, Train error: 0.224,
# rev_i: 24567, Train error: 0.224,
# rev_i: 24568, Train error: 0.224,
# rev_i: 24569, Train error: 0.224,
# rev_i: 24570, Train error: 0.224,
# rev_i: 24571, Train error: 0.224,
# rev_i: 24572, Train error: 0.224,
# rev_i: 24573, Train error: 0.224,
# rev_i: 24574, Train error: 0.224,
# rev_i: 24575, Train error: 0.224,
# rev_i: 24576, Train error: 0.224,
# rev_i: 24577, Train error: 0.224,
# rev_i: 24578, Train error: 0.224,
# rev_i: 24579, Train error: 0.224,
# rev_i: 24580, Train error: 0.224,
# rev_i: 24581, Train error: 0.224,
# rev_i: 24582, Train error: 0.224,
# rev_i: 24583, Train error: 0.224,
# rev_i: 24584, Train error: 0.224,
# rev_i: 24585, Train error: 0.224,
# rev_i: 24586, Train error: 0.224,
# rev_i: 24587, Train error: 0.224,
# rev_i: 24588, Train error: 0.224,
# rev_i: 24589, Train error: 0.224,
# rev_i: 24590, Train error: 0.224,
# rev_i: 24591, Train error: 0.224,
# rev_i: 24592, Train error: 0.224,
# rev_i: 24593, Train error: 0.224,
# rev_i: 24594, Train error: 0.224,
# rev_i: 24595, Train error: 0.224,
# rev_i: 24596, Train error: 0.224,
# rev_i: 24597, Train error: 0.224,
# rev_i: 24598, Train error: 0.224,
# rev_i: 24599, Train error: 0.224,
# rev_i: 24600, Train error: 0.224,
# rev_i: 24601, Train error: 0.224,
# rev_i: 24602, Train error: 0.224,
# rev_i: 24603, Train error: 0.224,
# rev_i: 24604, Train error: 0.224,
# rev_i: 24605, Train error: 0.224,
# rev_i: 24606, Train error: 0.224,
# rev_i: 24607, Train error: 0.224,
# rev_i: 24608, Train error: 0.224,
# rev_i: 24609, Train error: 0.224,
# rev_i: 24610, Train error: 0.224,
# rev_i: 24611, Train error: 0.224,
# rev_i: 24612, Train error: 0.224,
# rev_i: 24613, Train error: 0.224,
# rev_i: 24614, Train error: 0.224,
# rev_i: 24615, Train error: 0.224,
# rev_i: 24616, Train error: 0.224,
# rev_i: 24617, Train error: 0.224,
# rev_i: 24618, Train error: 0.224,
# rev_i: 24619, Train error: 0.224,
# rev_i: 24620, Train error: 0.224,
# rev_i: 24621, Train error: 0.224,
# rev_i: 24622, Train error: 0.224,
# rev_i: 24623, Train error: 0.224,
# rev_i: 24624, Train error: 0.224,
# rev_i: 24625, Train error: 0.224,
# rev_i: 24626, Train error: 0.224,
# rev_i: 24627, Train error: 0.224,
# rev_i: 24628, Train error: 0.224,
# rev_i: 24629, Train error: 0.224,
# rev_i: 24630, Train error: 0.224,
# rev_i: 24631, Train error: 0.224,
# rev_i: 24632, Train error: 0.224,
# rev_i: 24633, Train error: 0.224,
# rev_i: 24634, Train error: 0.224,
# rev_i: 24635, Train error: 0.224,
# rev_i: 24636, Train error: 0.224,
# rev_i: 24637, Train error: 0.224,
# rev_i: 24638, Train error: 0.224,
# rev_i: 24639, Train error: 0.224,
# rev_i: 24640, Train error: 0.224,
# rev_i: 24641, Train error: 0.224,
# rev_i: 24642, Train error: 0.224,
# rev_i: 24643, Train error: 0.224,
# rev_i: 24644, Train error: 0.224,
# rev_i: 24645, Train error: 0.224,
# rev_i: 24646, Train error: 0.224,
# rev_i: 24647, Train error: 0.224,
# rev_i: 24648, Train error: 0.224,
# rev_i: 24649, Train error: 0.224,
# rev_i: 24650, Train error: 0.224,
# rev_i: 24651, Train error: 0.224,
# rev_i: 24652, Train error: 0.224,
# rev_i: 24653, Train error: 0.224,
# rev_i: 24654, Train error: 0.224,
# rev_i: 24655, Train error: 0.224,
# rev_i: 24656, Train error: 0.224,
# rev_i: 24657, Train error: 0.224,
# rev_i: 24658, Train error: 0.224,
# rev_i: 24659, Train error: 0.224,
# rev_i: 24660, Train error: 0.224,
# rev_i: 24661, Train error: 0.224,
# rev_i: 24662, Train error: 0.224,
# rev_i: 24663, Train error: 0.224,
# rev_i: 24664, Train error: 0.224,
# rev_i: 24665, Train error: 0.224,
# rev_i: 24666, Train error: 0.224,
# rev_i: 24667, Train error: 0.224,
# rev_i: 24668, Train error: 0.224,
# rev_i: 24669, Train error: 0.224,
# rev_i: 24670, Train error: 0.224,
# rev_i: 24671, Train error: 0.224,
# rev_i: 24672, Train error: 0.224,
# rev_i: 24673, Train error: 0.224,
# rev_i: 24674, Train error: 0.224,
# rev_i: 24675, Train error: 0.224,
# rev_i: 24676, Train error: 0.224,
# rev_i: 24677, Train error: 0.224,
# rev_i: 24678, Train error: 0.224,
# rev_i: 24679, Train error: 0.224,
# rev_i: 24680, Train error: 0.224,
# rev_i: 24681, Train error: 0.224,
# rev_i: 24682, Train error: 0.224,
# rev_i: 24683, Train error: 0.224,
# rev_i: 24684, Train error: 0.224,
# rev_i: 24685, Train error: 0.224,
# rev_i: 24686, Train error: 0.224,
# rev_i: 24687, Train error: 0.224,
# rev_i: 24688, Train error: 0.224,
# rev_i: 24689, Train error: 0.224,
# rev_i: 24690, Train error: 0.224,
# rev_i: 24691, Train error: 0.224,
# rev_i: 24692, Train error: 0.224,
# rev_i: 24693, Train error: 0.224,
# rev_i: 24694, Train error: 0.224,
# rev_i: 24695, Train error: 0.224,
# rev_i: 24696, Train error: 0.224,
# rev_i: 24697, Train error: 0.224,
# rev_i: 24698, Train error: 0.224,
# rev_i: 24699, Train error: 0.224,
# rev_i: 24700, Train error: 0.224,
# rev_i: 24701, Train error: 0.224,
# rev_i: 24702, Train error: 0.224,
# rev_i: 24703, Train error: 0.224,
# rev_i: 24704, Train error: 0.224,
# rev_i: 24705, Train error: 0.224,
# rev_i: 24706, Train error: 0.224,
# rev_i: 24707, Train error: 0.224,
# rev_i: 24708, Train error: 0.224,
# rev_i: 24709, Train error: 0.224,
# rev_i: 24710, Train error: 0.224,
# rev_i: 24711, Train error: 0.224,
# rev_i: 24712, Train error: 0.224,
# rev_i: 24713, Train error: 0.224,
# rev_i: 24714, Train error: 0.224,
# rev_i: 24715, Train error: 0.224,
# rev_i: 24716, Train error: 0.224,
# rev_i: 24717, Train error: 0.224,
# rev_i: 24718, Train error: 0.224,
# rev_i: 24719, Train error: 0.224,
# rev_i: 24720, Train error: 0.224,
# rev_i: 24721, Train error: 0.224,
# rev_i: 24722, Train error: 0.224,
# rev_i: 24723, Train error: 0.224,
# rev_i: 24724, Train error: 0.224,
# rev_i: 24725, Train error: 0.224,
# rev_i: 24726, Train error: 0.224,
# rev_i: 24727, Train error: 0.224,
# rev_i: 24728, Train error: 0.224,
# rev_i: 24729, Train error: 0.224,
# rev_i: 24730, Train error: 0.224,
# rev_i: 24731, Train error: 0.224,
# rev_i: 24732, Train error: 0.224,
# rev_i: 24733, Train error: 0.224,
# rev_i: 24734, Train error: 0.224,
# rev_i: 24735, Train error: 0.224,
# rev_i: 24736, Train error: 0.224,
# rev_i: 24737, Train error: 0.224,
# rev_i: 24738, Train error: 0.224,
# rev_i: 24739, Train error: 0.224,
# rev_i: 24740, Train error: 0.224,
# rev_i: 24741, Train error: 0.224,
# rev_i: 24742, Train error: 0.224,
# rev_i: 24743, Train error: 0.224,
# rev_i: 24744, Train error: 0.224,
# rev_i: 24745, Train error: 0.224,
# rev_i: 24746, Train error: 0.224,
# rev_i: 24747, Train error: 0.224,
# rev_i: 24748, Train error: 0.224,
# rev_i: 24749, Train error: 0.224,
# rev_i: 24750, Train error: 0.224,
# rev_i: 24751, Train error: 0.224,
# rev_i: 24752, Train error: 0.224,
# rev_i: 24753, Train error: 0.224,
# rev_i: 24754, Train error: 0.224,
# rev_i: 24755, Train error: 0.224,
# rev_i: 24756, Train error: 0.224,
# rev_i: 24757, Train error: 0.224,
# rev_i: 24758, Train error: 0.224,
# rev_i: 24759, Train error: 0.224,
# rev_i: 24760, Train error: 0.224,
# rev_i: 24761, Train error: 0.224,
# rev_i: 24762, Train error: 0.224,
# rev_i: 24763, Train error: 0.224,
# rev_i: 24764, Train error: 0.224,
# rev_i: 24765, Train error: 0.224,
# rev_i: 24766, Train error: 0.224,
# rev_i: 24767, Train error: 0.224,
# rev_i: 24768, Train error: 0.224,
# rev_i: 24769, Train error: 0.224,
# rev_i: 24770, Train error: 0.224,
# rev_i: 24771, Train error: 0.224,
# rev_i: 24772, Train error: 0.224,
# rev_i: 24773, Train error: 0.224,
# rev_i: 24774, Train error: 0.224,
# rev_i: 24775, Train error: 0.224,
# rev_i: 24776, Train error: 0.224,
# rev_i: 24777, Train error: 0.224,
# rev_i: 24778, Train error: 0.224,
# rev_i: 24779, Train error: 0.224,
# rev_i: 24780, Train error: 0.224,
# rev_i: 24781, Train error: 0.224,
# rev_i: 24782, Train error: 0.224,
# rev_i: 24783, Train error: 0.224,
# rev_i: 24784, Train error: 0.224,
# rev_i: 24785, Train error: 0.224,
# rev_i: 24786, Train error: 0.224,
# rev_i: 24787, Train error: 0.224,
# rev_i: 24788, Train error: 0.224,
# rev_i: 24789, Train error: 0.224,
# rev_i: 24790, Train error: 0.224,
# rev_i: 24791, Train error: 0.224,
# rev_i: 24792, Train error: 0.224,
# rev_i: 24793, Train error: 0.224,
# rev_i: 24794, Train error: 0.224,
# rev_i: 24795, Train error: 0.224,
# rev_i: 24796, Train error: 0.224,
# rev_i: 24797, Train error: 0.224,
# rev_i: 24798, Train error: 0.224,
# rev_i: 24799, Train error: 0.224,
# rev_i: 24800, Train error: 0.224,
# rev_i: 24801, Train error: 0.224,
# rev_i: 24802, Train error: 0.224,
# rev_i: 24803, Train error: 0.224,
# rev_i: 24804, Train error: 0.224,
# rev_i: 24805, Train error: 0.224,
# rev_i: 24806, Train error: 0.224,
# rev_i: 24807, Train error: 0.224,
# rev_i: 24808, Train error: 0.224,
# rev_i: 24809, Train error: 0.224,
# rev_i: 24810, Train error: 0.224,
# rev_i: 24811, Train error: 0.224,
# rev_i: 24812, Train error: 0.224,
# rev_i: 24813, Train error: 0.224,
# rev_i: 24814, Train error: 0.224,
# rev_i: 24815, Train error: 0.224,
# rev_i: 24816, Train error: 0.224,
# rev_i: 24817, Train error: 0.224,
# rev_i: 24818, Train error: 0.224,
# rev_i: 24819, Train error: 0.224,
# rev_i: 24820, Train error: 0.224,
# rev_i: 24821, Train error: 0.224,
# rev_i: 24822, Train error: 0.224,
# rev_i: 24823, Train error: 0.224,
# rev_i: 24824, Train error: 0.224,
# rev_i: 24825, Train error: 0.224,
# rev_i: 24826, Train error: 0.224,
# rev_i: 24827, Train error: 0.224,
# rev_i: 24828, Train error: 0.224,
# rev_i: 24829, Train error: 0.224,
# rev_i: 24830, Train error: 0.224,
# rev_i: 24831, Train error: 0.224,
# rev_i: 24832, Train error: 0.224,
# rev_i: 24833, Train error: 0.224,
# rev_i: 24834, Train error: 0.224,
# rev_i: 24835, Train error: 0.224,
# rev_i: 24836, Train error: 0.224,
# rev_i: 24837, Train error: 0.224,
# rev_i: 24838, Train error: 0.224,
# rev_i: 24839, Train error: 0.224,
# rev_i: 24840, Train error: 0.224,
# rev_i: 24841, Train error: 0.224,
# rev_i: 24842, Train error: 0.224,
# rev_i: 24843, Train error: 0.224,
# rev_i: 24844, Train error: 0.224,
# rev_i: 24845, Train error: 0.224,
# rev_i: 24846, Train error: 0.224,
# rev_i: 24847, Train error: 0.224,
# rev_i: 24848, Train error: 0.224,
# rev_i: 24849, Train error: 0.224,
# rev_i: 24850, Train error: 0.224,
# rev_i: 24851, Train error: 0.224,
# rev_i: 24852, Train error: 0.224,
# rev_i: 24853, Train error: 0.224,
# rev_i: 24854, Train error: 0.224,
# rev_i: 24855, Train error: 0.224,
# rev_i: 24856, Train error: 0.224,
# rev_i: 24857, Train error: 0.224,
# rev_i: 24858, Train error: 0.224,
# rev_i: 24859, Train error: 0.224,
# rev_i: 24860, Train error: 0.224,
# rev_i: 24861, Train error: 0.224,
# rev_i: 24862, Train error: 0.224,
# rev_i: 24863, Train error: 0.224,
# rev_i: 24864, Train error: 0.224,
# rev_i: 24865, Train error: 0.224,
# rev_i: 24866, Train error: 0.224,
# rev_i: 24867, Train error: 0.224,
# rev_i: 24868, Train error: 0.224,
# rev_i: 24869, Train error: 0.224,
# rev_i: 24870, Train error: 0.224,
# rev_i: 24871, Train error: 0.224,
# rev_i: 24872, Train error: 0.224,
# rev_i: 24873, Train error: 0.224,
# rev_i: 24874, Train error: 0.224,
# rev_i: 24875, Train error: 0.224,
# rev_i: 24876, Train error: 0.224,
# rev_i: 24877, Train error: 0.224,
# rev_i: 24878, Train error: 0.224,
# rev_i: 24879, Train error: 0.224,
# rev_i: 24880, Train error: 0.224,
# rev_i: 24881, Train error: 0.224,
# rev_i: 24882, Train error: 0.224,
# rev_i: 24883, Train error: 0.224,
# rev_i: 24884, Train error: 0.224,
# rev_i: 24885, Train error: 0.224,
# rev_i: 24886, Train error: 0.224,
# rev_i: 24887, Train error: 0.224,
# rev_i: 24888, Train error: 0.224,
# rev_i: 24889, Train error: 0.224,
# rev_i: 24890, Train error: 0.224,
# rev_i: 24891, Train error: 0.224,
# rev_i: 24892, Train error: 0.224,
# rev_i: 24893, Train error: 0.224,
# rev_i: 24894, Train error: 0.224,
# rev_i: 24895, Train error: 0.224,
# rev_i: 24896, Train error: 0.224,
# rev_i: 24897, Train error: 0.224,
# rev_i: 24898, Train error: 0.224,
# rev_i: 24899, Train error: 0.224,
# rev_i: 24900, Train error: 0.224,
# rev_i: 24901, Train error: 0.224,
# rev_i: 24902, Train error: 0.224,
# rev_i: 24903, Train error: 0.224,
# rev_i: 24904, Train error: 0.224,
# rev_i: 24905, Train error: 0.224,
# rev_i: 24906, Train error: 0.224,
# rev_i: 24907, Train error: 0.224,
# rev_i: 24908, Train error: 0.224,
# rev_i: 24909, Train error: 0.224,
# rev_i: 24910, Train error: 0.224,
# rev_i: 24911, Train error: 0.224,
# rev_i: 24912, Train error: 0.224,
# rev_i: 24913, Train error: 0.224,
# rev_i: 24914, Train error: 0.224,
# rev_i: 24915, Train error: 0.224,
# rev_i: 24916, Train error: 0.224,
# rev_i: 24917, Train error: 0.224,
# rev_i: 24918, Train error: 0.224,
# rev_i: 24919, Train error: 0.224,
# rev_i: 24920, Train error: 0.224,
# rev_i: 24921, Train error: 0.224,
# rev_i: 24922, Train error: 0.224,
# rev_i: 24923, Train error: 0.224,
# rev_i: 24924, Train error: 0.224,
# rev_i: 24925, Train error: 0.224,
# rev_i: 24926, Train error: 0.224,
# rev_i: 24927, Train error: 0.224,
# rev_i: 24928, Train error: 0.224,
# rev_i: 24929, Train error: 0.224,
# rev_i: 24930, Train error: 0.224,
# rev_i: 24931, Train error: 0.224,
# rev_i: 24932, Train error: 0.224,
# rev_i: 24933, Train error: 0.224,
# rev_i: 24934, Train error: 0.224,
# rev_i: 24935, Train error: 0.224,
# rev_i: 24936, Train error: 0.224,
# rev_i: 24937, Train error: 0.224,
# rev_i: 24938, Train error: 0.224,
# rev_i: 24939, Train error: 0.224,
# rev_i: 24940, Train error: 0.224,
# rev_i: 24941, Train error: 0.224,
# rev_i: 24942, Train error: 0.224,
# rev_i: 24943, Train error: 0.224,
# rev_i: 24944, Train error: 0.224,
# rev_i: 24945, Train error: 0.224,
# rev_i: 24946, Train error: 0.224,
# rev_i: 24947, Train error: 0.224,
# rev_i: 24948, Train error: 0.224,
# rev_i: 24949, Train error: 0.224,
# rev_i: 24950, Train error: 0.224,
# rev_i: 24951, Train error: 0.224,
# rev_i: 24952, Train error: 0.224,
# rev_i: 24953, Train error: 0.224,
# rev_i: 24954, Train error: 0.224,
# rev_i: 24955, Train error: 0.224,
# rev_i: 24956, Train error: 0.224,
# rev_i: 24957, Train error: 0.224,
# rev_i: 24958, Train error: 0.224,
# rev_i: 24959, Train error: 0.224,
# rev_i: 24960, Train error: 0.224,
# rev_i: 24961, Train error: 0.224,
# rev_i: 24962, Train error: 0.224,
# rev_i: 24963, Train error: 0.224,
# rev_i: 24964, Train error: 0.224,
# rev_i: 24965, Train error: 0.224,
# rev_i: 24966, Train error: 0.224,
# rev_i: 24967, Train error: 0.224,
# rev_i: 24968, Train error: 0.224,
# rev_i: 24969, Train error: 0.224,
# rev_i: 24970, Train error: 0.224,
# rev_i: 24971, Train error: 0.224,
# rev_i: 24972, Train error: 0.224,
# rev_i: 24973, Train error: 0.224,
# rev_i: 24974, Train error: 0.224,
# rev_i: 24975, Train error: 0.224,
# rev_i: 24976, Train error: 0.224,
# rev_i: 24977, Train error: 0.224,
# rev_i: 24978, Train error: 0.224,
# rev_i: 24979, Train error: 0.224,
# rev_i: 24980, Train error: 0.224,
# rev_i: 24981, Train error: 0.224,
# rev_i: 24982, Train error: 0.224,
# rev_i: 24983, Train error: 0.224,
# rev_i: 24984, Train error: 0.224,
# rev_i: 24985, Train error: 0.224,
# rev_i: 24986, Train error: 0.224,
# rev_i: 24987, Train error: 0.224,
# rev_i: 24988, Train error: 0.224,
# rev_i: 24989, Train error: 0.224,
# rev_i: 24990, Train error: 0.224,
# rev_i: 24991, Train error: 0.224,
# rev_i: 24992, Train error: 0.224,
# rev_i: 24993, Train error: 0.224,
# rev_i: 24994, Train error: 0.224,
# rev_i: 24995, Train error: 0.224,
# rev_i: 24996, Train error: 0.224,
# rev_i: 24997, Train error: 0.224,
# rev_i: 24998, Train error: 0.224,
# rev_i: 24999, Train error: 0.224,

# %%
# np.savetxt('layer1_weights.csv', layer1.weights, delimiter=',')
# np.savetxt('layer2_weights.csv', layer2.weights, delimiter=',')

# %%
import json

# %%
# with open('word_to_index.txt', 'w') as f:
#     json.dump(word_to_index, f)

# %%
with open('word_to_index.txt', 'r') as f:
    word_to_index_2 = json.load(f)

# %%
type(word_to_index_2)
# Out:
# dict

# %%
trained_layer2_weights = np.loadtxt('layer2_weights.csv', delimiter=',')

# %%
trained_layer2_weights.shape
# Out:
# (60, 74072)

# %%
from collections import Counter

# %%
def similar(target):
    target_index = word_to_index_2[target]
    scores = Counter()
    for word, index in word_to_index_2.items():
        # Finding Euclidian distance
        scores[word] = -np.linalg.norm(trained_layer2_weights.T[index] - trained_layer2_weights.T[target_index])
    
    return scores.most_common(10)

# %%
similar('mom')
# Out:
# [('mom', -0.0),
#  ('stereotypical', -2.023294895506832),
#  ('dad', -2.0617622934500637),
#  ('hagar', -2.084669750267174),
#  ('brother', -2.140831226033868),
#  ('demeanor', -2.174428170786136),
#  ('alvin', -2.2208992380957158),
#  ('mick', -2.2210772070231797),
#  ('cleavage', -2.2242464507329878),
#  ('grief', -2.2304078727979166)]

# %% [markdown]
# ## 2. Word analogies (Dad - Men + Women ~= Mom)

# %%
def analogy(positive, negative):
    
    result_vector = np.zeros(len(trained_layer2_weights))
    for word in positive:
        result_vector += trained_layer2_weights.T[word_to_index_2[word]]
    for word in negative:
        result_vector -= trained_layer2_weights.T[word_to_index_2[word]]
        
    scores = Counter()
    for word, index in word_to_index_2.items():
        # Finding Euclidian distance
        scores[word] = -np.linalg.norm(trained_layer2_weights.T[index] - result_vector)
                                    
    return scores.most_common(10)

# %%
analogy(['sister', 'he'], ['she'])
# Out:
# [('sister', -3.1472198923033656),
#  ('lover', -3.7993884458287304),
#  ('fellow', -3.8541980685138566),
#  ('ego', -3.883074223273408),
#  ('favorite', -3.9566316807460407),
#  ('laboratory', -3.9848490754376145),
#  ('chest', -4.0148546968206125),
#  ('les', -4.024022206780802),
#  ('creations', -4.024862619970713),
#  ('he', -4.027725854647477)]

# %% [markdown]
# Main takeaway is
#     - carefully choose the input and the target values to learn richer meanings
#     - Learning is all about minimizing errors
